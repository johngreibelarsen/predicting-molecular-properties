# %% [markdown]
# ### The Data
# This book builds on previous notebooks regarding feature enginnering and feature selection however in this book we will train a model per 1JHC and 1JHN coupling types. We will additionally feature enhance those datasets by more details about the eletronic structure of the molecules.
#
# Note: this book will only consider data from the following csv files: train, structures and molecule_structures

# %%
import pandas as pd

input_folder = './input'

train = pd.read_csv(f'{input_folder}/feature_files/1JHC.csv')

# %%
pd.set_option('display.max_columns', None)

train.head()

# %%
train.dtypes

# %%
import numpy as np

def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                c_prec = df[col].apply(lambda x: np.finfo(x).precision).max()
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max and c_prec == np.finfo(np.float16).precision:
                    df[col] = df[col].astype(np.float16)
                else:
                    df[col] = df[col].astype(np.float32)
                    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

#                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max and c_prec == np.finfo(np.float32).precision:
#                    df[col] = df[col].astype(np.float32)

# %%
train = reduce_mem_usage(train)
train.dtypes
# Out:
# Mem. usage decreased to 184.02 Mb (61.8% reduction)
# atom_index_0                                   int8
# atom_index_1                                   int8
# scalar_coupling_constant                    float32
# atom_0                                       object
# x_0                                         float32
# y_0                                         float32
# z_0                                         float32
# atom_1                                       object
# x_1                                         float32
# y_1                                         float32
# z_1                                         float32
# atom_0_CH3                                     int8
# atom_1_CH3                                     int8
# atom_0_CH2                                     int8
# atom_1_CH2                                     int8
# atom_0_CH1                                     int8
# atom_1_CH1                                     int8
# atom_0_CH0                                     int8
# atom_1_CH0                                     int8
# atom_0_NH2                                     int8
# atom_1_NH2                                     int8
# atom_0_NH1                                     int8
# atom_1_NH1                                     int8
# atom_0_NH0                                     int8
# atom_1_NH0                                     int8
# atom_0_OH1                                     int8
# atom_1_OH1                                     int8
# atom_0_OH0                                     int8
# atom_1_OH0                                     int8
# is_in_ring                                     int8
#                                              ...
# molecule_dist_max                           float32
# molecule_dist_std                           float32
# atom_0_couples_count                           int8
# atom_1_couples_count                           int8
# molecule_atom_index_0_count                   int16
# molecule_atom_index_1_count                   int16
# molecule_atom_index_0_distance_mean         float32
# molecule_atom_index_0_distance_mean_diff    float32
# molecule_atom_index_0_distance_mean_div     float32
# molecule_atom_index_0_distance_std          float32
# molecule_atom_index_0_distance_std_diff     float32
# molecule_atom_index_0_distance_std_div      float32
# molecule_atom_index_0_distance_max          float32
# molecule_atom_index_0_distance_max_diff     float32
# molecule_atom_index_0_distance_max_div      float32
# molecule_atom_index_0_distance_min          float32
# molecule_atom_index_0_distance_min_diff     float32
# molecule_atom_index_0_distance_min_div      float32
# molecule_atom_index_1_distance_mean         float32
# molecule_atom_index_1_distance_mean_diff    float32
# molecule_atom_index_1_distance_mean_div     float32
# molecule_atom_index_1_distance_std          float32
# molecule_atom_index_1_distance_std_diff     float32
# molecule_atom_index_1_distance_std_div      float32
# molecule_atom_index_1_distance_max          float32
# molecule_atom_index_1_distance_max_diff     float32
# molecule_atom_index_1_distance_max_div      float32
# molecule_atom_index_1_distance_min          float32
# molecule_atom_index_1_distance_min_diff     float32
# molecule_atom_index_1_distance_min_div      float32
# Length: 89, dtype: object

# %% [markdown]
# #### Remove none important features

# %%
#train = train.drop('NB_left_atom', axis=1)
#train = train.drop('NB_left_group', axis=1)

#train = train.drop('NB_center_atom', axis=1)
#train = train.drop('NB_center_group', axis=1)

#train = train.drop('NB_right_atom', axis=1)
#train = train.drop('NB_right_group', axis=1)

#train = train.drop('x_0', axis=1)
#train = train.drop('y_0', axis=1)
#train = train.drop('z_0', axis=1)

#train = train.drop('x_1', axis=1)
#train = train.drop('y_1', axis=1)
#train = train.drop('z_1', axis=1)

#train = train.drop('molecule_atom_index_0_distance_std', axis=1)
#train = train.drop('molecule_atom_index_1_distance_std', axis=1)

#train = train.drop('molecule_atom_index_0_distance_min_div', axis=1)
#train = train.drop('molecule_atom_index_1_distance_min_div', axis=1)

#train = train.drop('molecule_atom_index_0_distance_min_diff', axis=1)
#train = train.drop('molecule_atom_index_1_distance_min_diff', axis=1)

#train = train.drop('molecule_atom_index_0_distance_max_div', axis=1)
#train = train.drop('molecule_atom_index_1_distance_max_div', axis=1)

#train = train.drop('molecule_atom_index_0_distance_max_diff', axis=1)
#train = train.drop('molecule_atom_index_1_distance_max_diff', axis=1)

#train = train.drop('molecule_atom_index_0_distance_std_div', axis=1)
#train = train.drop('molecule_atom_index_1_distance_std_div', axis=1)

#train = train.drop('molecule_atom_index_0_distance_std_diff', axis=1)
#train = train.drop('molecule_atom_index_1_distance_std_diff', axis=1)

#train = train.drop('molecule_atom_index_0_distance_mean_div', axis=1)
#train = train.drop('molecule_atom_index_1_distance_mean_div', axis=1)

#train = train.drop('molecule_atom_index_0_distance_mean_diff', axis=1)
#train = train.drop('molecule_atom_index_1_distance_mean_diff', axis=1)

# %% [markdown]
# #### Fill NaN

# %%
train[train.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [atom_index_0, atom_index_1, scalar_coupling_constant, atom_0, x_0, y_0, z_0, atom_1, x_1, y_1, z_1, atom_0_CH3, atom_1_CH3, atom_0_CH2, atom_1_CH2, atom_0_CH1, atom_1_CH1, atom_0_CH0, atom_1_CH0, atom_0_NH2, atom_1_NH2, atom_0_NH1, atom_1_NH1, atom_0_NH0, atom_1_NH0, atom_0_OH1, atom_1_OH1, atom_0_OH0, atom_1_OH0, is_in_ring, has_aromatic_bond, is_primary_amide, is_secondary_amide, is_tertiary_amide, is_ester, is_carbonyl, bond_order, NB_left_atom, NB_left_group, NB_center_atom, NB_center_group, NB_right_atom, NB_right_group, NB_all_groups, NB_in_ring, NB_is_aromatic, NB_is_primary_amide, NB_is_secondary_amide, NB_is_tertiary_amide, NB_is_ester, NB_is_carbonyl, NB_is_hydroxyl, abs_dx, abs_dy, abs_dz, distance, molecule_couples, molecule_dist_mean, molecule_dist_min, molecule_dist_max, molecule_dist_std, atom_0_couples_count, atom_1_couples_count, molecule_atom_index_0_count, molecule_atom_index_1_count, molecule_atom_index_0_distance_mean, molecule_atom_index_0_distance_mean_diff, molecule_atom_index_0_distance_mean_div, molecule_atom_index_0_distance_std, molecule_atom_index_0_distance_std_diff, molecule_atom_index_0_distance_std_div, molecule_atom_index_0_distance_max, molecule_atom_index_0_distance_max_diff, molecule_atom_index_0_distance_max_div, molecule_atom_index_0_distance_min, molecule_atom_index_0_distance_min_diff, molecule_atom_index_0_distance_min_div, molecule_atom_index_1_distance_mean, molecule_atom_index_1_distance_mean_diff, molecule_atom_index_1_distance_mean_div, molecule_atom_index_1_distance_std, molecule_atom_index_1_distance_std_diff, molecule_atom_index_1_distance_std_div, molecule_atom_index_1_distance_max, molecule_atom_index_1_distance_max_diff, molecule_atom_index_1_distance_max_div, molecule_atom_index_1_distance_min, molecule_atom_index_1_distance_min_diff, molecule_atom_index_1_distance_min_div]
# Index: []
#
# [0 rows x 89 columns]

# %%
# If needed based on outcome of above

train.NB_all_groups.fillna('', inplace=True)
train.fillna(0, inplace=True)

# %% [markdown]
# ### Data splitting

# %%
from sklearn.model_selection import train_test_split

y = train['scalar_coupling_constant']
X = train.drop('scalar_coupling_constant', axis=1)
    
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state = 13, test_size = 0.02)

# %% [markdown]
# #### Cleanup - we need the resources

# %%
import gc

del X_train
del X_valid
del y_train
del y_valid
del X
del y


gc.collect()
# Out:
# 27

# %% [markdown]
# ### The model

# %%
import numpy as np
from catboost import CatBoostRegressor

cat_features_index = np.where(X_train.dtypes != np.float32)[0]

model = CatBoostRegressor(iterations=8000, depth= 14, random_seed = 13, task_type = "GPU", devices='0', gpu_ram_part=0.95, gpu_cat_features_storage='CpuPinnedMemory')
model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=cat_features_index, logging_level='Verbose')

# test: 2.1113 1JHC {iter=2000, depth=13, all features}
# test: ~2.03 1JHC {iter=3500, depth=14, all features - NB_s and x_0, y_0 ..}
# test: 1.8956 1JHC {iter=5000, depth=14, all features}
# test: ~1.84 1JHC {iter=10000, depth=14, all features}

# test: ~1.xx 1JHC {iter=10000, depth=14, all features} - BAD ALLOCATION
# test: ~1.74 1JHC {iter=12500, depth=14, all features} - BAD ALLOCATION



# test: 1.5779 1JHN {iter=2000, depth=13, all features}
# test: 1.5171 1JHN {iter=2000, depth=13, only NB_all_groups}
# Out:
# 0:	learn: 93.8407323	test: 93.6088192	best: 93.6088192 (0)	total: 527ms	remaining: 1h 10m 14s
# 1:	learn: 91.0475169	test: 90.8187083	best: 90.8187083 (1)	total: 1.05s	remaining: 1h 9m 53s
# 2:	learn: 88.3333805	test: 88.1110499	best: 88.1110499 (2)	total: 1.52s	remaining: 1h 7m 31s
# 3:	learn: 85.7047407	test: 85.4862558	best: 85.4862558 (3)	total: 2s	remaining: 1h 6m 38s
# 4:	learn: 83.1537198	test: 82.9340866	best: 82.9340866 (4)	total: 2.48s	remaining: 1h 6m 2s
# 5:	learn: 80.6762021	test: 80.4622946	best: 80.4622946 (5)	total: 3.02s	remaining: 1h 7m 7s
# 6:	learn: 78.2723858	test: 78.0628890	best: 78.0628890 (6)	total: 3.56s	remaining: 1h 7m 50s
# 7:	learn: 75.9435942	test: 75.7369097	best: 75.7369097 (7)	total: 4.12s	remaining: 1h 8m 32s
# 8:	learn: 73.6836078	test: 73.4810055	best: 73.4810055 (8)	total: 4.68s	remaining: 1h 9m 18s
# 9:	learn: 71.4924134	test: 71.2935088	best: 71.2935088 (9)	total: 5.25s	remaining: 1h 9m 50s
# 10:	learn: 69.3635988	test: 69.1683448	best: 69.1683448 (10)	total: 5.84s	remaining: 1h 10m 45s
# 11:	learn: 67.3030725	test: 67.1094631	best: 67.1094631 (11)	total: 6.36s	remaining: 1h 10m 35s
# 12:	learn: 65.3005240	test: 65.1102796	best: 65.1102796 (12)	total: 6.87s	remaining: 1h 10m 22s
# 13:	learn: 63.3616600	test: 63.1738247	best: 63.1738247 (13)	total: 7.46s	remaining: 1h 10m 52s
# 14:	learn: 61.4799822	test: 61.2934191	best: 61.2934191 (14)	total: 7.96s	remaining: 1h 10m 35s
# 15:	learn: 59.6547633	test: 59.4702884	best: 59.4702884 (15)	total: 8.4s	remaining: 1h 9m 53s
# 16:	learn: 57.8829250	test: 57.7032662	best: 57.7032662 (16)	total: 8.91s	remaining: 1h 9m 43s
# 17:	learn: 56.1611469	test: 55.9838232	best: 55.9838232 (17)	total: 9.42s	remaining: 1h 9m 37s
# 18:	learn: 54.4954986	test: 54.3221532	best: 54.3221532 (18)	total: 9.9s	remaining: 1h 9m 17s
# 19:	learn: 52.8785014	test: 52.7047367	best: 52.7047367 (19)	total: 10.5s	remaining: 1h 9m 34s
# 20:	learn: 51.3105353	test: 51.1393950	best: 51.1393950 (20)	total: 11s	remaining: 1h 9m 42s
# 21:	learn: 49.7896095	test: 49.6197309	best: 49.6197309 (21)	total: 11.6s	remaining: 1h 9m 51s
# 22:	learn: 48.3124157	test: 48.1444180	best: 48.1444180 (22)	total: 12.1s	remaining: 1h 9m 59s
# 23:	learn: 46.8874779	test: 46.7214625	best: 46.7214625 (23)	total: 12.6s	remaining: 1h 9m 50s
# 24:	learn: 45.4990531	test: 45.3340084	best: 45.3340084 (24)	total: 13.1s	remaining: 1h 9m 48s
# 25:	learn: 44.1521166	test: 43.9899382	best: 43.9899382 (25)	total: 13.7s	remaining: 1h 9m 48s
# 26:	learn: 42.8506775	test: 42.6901091	best: 42.6901091 (26)	total: 14.2s	remaining: 1h 9m 38s
# 27:	learn: 41.5864747	test: 41.4276756	best: 41.4276756 (27)	total: 14.7s	remaining: 1h 9m 53s
# 28:	learn: 40.3590660	test: 40.2044777	best: 40.2044777 (28)	total: 15.3s	remaining: 1h 9m 55s
# 29:	learn: 39.1718619	test: 39.0202623	best: 39.0202623 (29)	total: 15.7s	remaining: 1h 9m 42s
# 30:	learn: 38.0201874	test: 37.8692272	best: 37.8692272 (30)	total: 16.3s	remaining: 1h 9m 50s
# 31:	learn: 36.9000336	test: 36.7507888	best: 36.7507888 (31)	total: 16.8s	remaining: 1h 9m 42s
# 32:	learn: 35.8144687	test: 35.6675197	best: 35.6675197 (32)	total: 17.2s	remaining: 1h 9m 21s
# 33:	learn: 34.7622273	test: 34.6160581	best: 34.6160581 (33)	total: 17.8s	remaining: 1h 9m 39s
# 34:	learn: 33.7429744	test: 33.5989340	best: 33.5989340 (34)	total: 18.4s	remaining: 1h 9m 41s
# 35:	learn: 32.7502619	test: 32.6070236	best: 32.6070236 (35)	total: 18.9s	remaining: 1h 9m 49s
# 36:	learn: 31.7898011	test: 31.6485041	best: 31.6485041 (36)	total: 19.4s	remaining: 1h 9m 37s
# 37:	learn: 30.8583076	test: 30.7188926	best: 30.7188926 (37)	total: 20s	remaining: 1h 9m 44s
# 38:	learn: 29.9527445	test: 29.8150712	best: 29.8150712 (38)	total: 20.5s	remaining: 1h 9m 38s
# 39:	learn: 29.0749745	test: 28.9402151	best: 28.9402151 (39)	total: 21s	remaining: 1h 9m 35s
# 40:	learn: 28.2255862	test: 28.0924129	best: 28.0924129 (40)	total: 21.4s	remaining: 1h 9m 22s
# 41:	learn: 27.4019062	test: 27.2689404	best: 27.2689404 (41)	total: 22s	remaining: 1h 9m 20s
# 42:	learn: 26.6075711	test: 26.4769064	best: 26.4769064 (42)	total: 22.5s	remaining: 1h 9m 23s
# 43:	learn: 25.8331380	test: 25.7031828	best: 25.7031828 (43)	total: 23s	remaining: 1h 9m 26s
# 44:	learn: 25.0813390	test: 24.9518925	best: 24.9518925 (44)	total: 23.6s	remaining: 1h 9m 33s
# 45:	learn: 24.3523801	test: 24.2244392	best: 24.2244392 (45)	total: 24.2s	remaining: 1h 9m 44s
# 46:	learn: 23.6464622	test: 23.5202096	best: 23.5202096 (46)	total: 24.7s	remaining: 1h 9m 44s
# 47:	learn: 22.9639925	test: 22.8398601	best: 22.8398601 (47)	total: 25.3s	remaining: 1h 9m 48s
# 48:	learn: 22.2998774	test: 22.1767816	best: 22.1767816 (48)	total: 25.8s	remaining: 1h 9m 49s
# 49:	learn: 21.6555675	test: 21.5338151	best: 21.5338151 (49)	total: 26.3s	remaining: 1h 9m 46s
# 50:	learn: 21.0328230	test: 20.9118048	best: 20.9118048 (50)	total: 26.9s	remaining: 1h 9m 45s
# 51:	learn: 20.4287213	test: 20.3076200	best: 20.3076200 (51)	total: 27.4s	remaining: 1h 9m 52s
# 52:	learn: 19.8413324	test: 19.7219448	best: 19.7219448 (52)	total: 28s	remaining: 1h 9m 57s
# 53:	learn: 19.2725000	test: 19.1539825	best: 19.1539825 (53)	total: 28.5s	remaining: 1h 10m
# 54:	learn: 18.7230180	test: 18.6051611	best: 18.6051611 (54)	total: 29.2s	remaining: 1h 10m 13s
# 55:	learn: 18.1917409	test: 18.0742862	best: 18.0742862 (55)	total: 29.7s	remaining: 1h 10m 16s
# 56:	learn: 17.6749241	test: 17.5572571	best: 17.5572571 (56)	total: 30.4s	remaining: 1h 10m 30s
# 57:	learn: 17.1755876	test: 17.0591828	best: 17.0591828 (57)	total: 30.9s	remaining: 1h 10m 28s
# 58:	learn: 16.6897272	test: 16.5742716	best: 16.5742716 (58)	total: 31.5s	remaining: 1h 10m 38s
# 59:	learn: 16.2191771	test: 16.1045181	best: 16.1045181 (59)	total: 32s	remaining: 1h 10m 33s
# 60:	learn: 15.7645066	test: 15.6513698	best: 15.6513698 (60)	total: 32.5s	remaining: 1h 10m 33s
# 61:	learn: 15.3246462	test: 15.2125085	best: 15.2125085 (61)	total: 33s	remaining: 1h 10m 28s
# 62:	learn: 14.8976496	test: 14.7862236	best: 14.7862236 (62)	total: 33.5s	remaining: 1h 10m 26s
# 63:	learn: 14.4824063	test: 14.3717489	best: 14.3717489 (63)	total: 34.1s	remaining: 1h 10m 33s
# 64:	learn: 14.0806737	test: 13.9712605	best: 13.9712605 (64)	total: 34.7s	remaining: 1h 10m 33s
# 65:	learn: 13.6902452	test: 13.5818635	best: 13.5818635 (65)	total: 35.3s	remaining: 1h 10m 40s
# 66:	learn: 13.3148691	test: 13.2067133	best: 13.2067133 (66)	total: 35.8s	remaining: 1h 10m 40s
# 67:	learn: 12.9497178	test: 12.8427263	best: 12.8427263 (67)	total: 36.4s	remaining: 1h 10m 50s
# 68:	learn: 12.5965676	test: 12.4900200	best: 12.4900200 (68)	total: 37s	remaining: 1h 10m 51s
# 69:	learn: 12.2549101	test: 12.1493245	best: 12.1493245 (69)	total: 37.5s	remaining: 1h 10m 53s
# 70:	learn: 11.9231555	test: 11.8186923	best: 11.8186923 (70)	total: 38.1s	remaining: 1h 10m 54s
# 71:	learn: 11.6032334	test: 11.4989696	best: 11.4989696 (71)	total: 38.7s	remaining: 1h 11m 1s
# 72:	learn: 11.2928374	test: 11.1896863	best: 11.1896863 (72)	total: 39.3s	remaining: 1h 11m 4s
# 73:	learn: 10.9934169	test: 10.8913446	best: 10.8913446 (73)	total: 39.9s	remaining: 1h 11m 10s
# 74:	learn: 10.7031003	test: 10.6025033	best: 10.6025033 (74)	total: 40.5s	remaining: 1h 11m 16s
# 75:	learn: 10.4221865	test: 10.3235491	best: 10.3235491 (75)	total: 41s	remaining: 1h 11m 16s
# 76:	learn: 10.1520274	test: 10.0543807	best: 10.0543807 (76)	total: 41.6s	remaining: 1h 11m 15s
# 77:	learn: 9.8899077	test: 9.7935999	best: 9.7935999 (77)	total: 42.2s	remaining: 1h 11m 21s
# 78:	learn: 9.6362634	test: 9.5417845	best: 9.5417845 (78)	total: 42.7s	remaining: 1h 11m 24s
# 79:	learn: 9.3904678	test: 9.2967257	best: 9.2967257 (79)	total: 43.3s	remaining: 1h 11m 27s
# 80:	learn: 9.1525995	test: 9.0599025	best: 9.0599025 (80)	total: 43.9s	remaining: 1h 11m 30s
# 81:	learn: 8.9233943	test: 8.8316003	best: 8.8316003 (81)	total: 44.5s	remaining: 1h 11m 36s
# 82:	learn: 8.7028386	test: 8.6126599	best: 8.6126599 (82)	total: 45s	remaining: 1h 11m 35s
# 83:	learn: 8.4886093	test: 8.3991094	best: 8.3991094 (83)	total: 45.6s	remaining: 1h 11m 39s
# 84:	learn: 8.2826947	test: 8.1948569	best: 8.1948569 (84)	total: 46.2s	remaining: 1h 11m 40s
# 85:	learn: 8.0821601	test: 7.9962762	best: 7.9962762 (85)	total: 46.8s	remaining: 1h 11m 43s
# 86:	learn: 7.8895515	test: 7.8049961	best: 7.8049961 (86)	total: 47.3s	remaining: 1h 11m 45s
# 87:	learn: 7.7022169	test: 7.6184722	best: 7.6184722 (87)	total: 48s	remaining: 1h 11m 57s
# 88:	learn: 7.5215349	test: 7.4393888	best: 7.4393888 (88)	total: 48.7s	remaining: 1h 12m 4s
# 89:	learn: 7.3477264	test: 7.2665711	best: 7.2665711 (89)	total: 49.3s	remaining: 1h 12m 8s
# 90:	learn: 7.1805781	test: 7.1004325	best: 7.1004325 (90)	total: 49.7s	remaining: 1h 12m 1s
# 91:	learn: 7.0184356	test: 6.9403509	best: 6.9403509 (91)	total: 50.4s	remaining: 1h 12m 8s
# 92:	learn: 6.8618448	test: 6.7859358	best: 6.7859358 (92)	total: 50.9s	remaining: 1h 12m 10s
# 93:	learn: 6.7110248	test: 6.6369855	best: 6.6369855 (93)	total: 51.5s	remaining: 1h 12m 11s
# 94:	learn: 6.5661203	test: 6.4935743	best: 6.4935743 (94)	total: 52s	remaining: 1h 12m 9s
# 95:	learn: 6.4271668	test: 6.3556408	best: 6.3556408 (95)	total: 52.6s	remaining: 1h 12m 11s
# 96:	learn: 6.2926093	test: 6.2228022	best: 6.2228022 (96)	total: 53.3s	remaining: 1h 12m 20s
# 97:	learn: 6.1643064	test: 6.0963826	best: 6.0963826 (97)	total: 53.8s	remaining: 1h 12m 20s
# 98:	learn: 6.0394283	test: 5.9728836	best: 5.9728836 (98)	total: 54.4s	remaining: 1h 12m 17s
# 99:	learn: 5.9195343	test: 5.8542714	best: 5.8542714 (99)	total: 55s	remaining: 1h 12m 21s
# 100:	learn: 5.8037053	test: 5.7401107	best: 5.7401107 (100)	total: 55.5s	remaining: 1h 12m 22s
# 101:	learn: 5.6920037	test: 5.6305226	best: 5.6305226 (101)	total: 56.1s	remaining: 1h 12m 22s
# 102:	learn: 5.5858224	test: 5.5256192	best: 5.5256192 (102)	total: 56.6s	remaining: 1h 12m 20s
# 103:	learn: 5.4844282	test: 5.4257777	best: 5.4257777 (103)	total: 57.2s	remaining: 1h 12m 24s
# 104:	learn: 5.3860236	test: 5.3295061	best: 5.3295061 (104)	total: 57.8s	remaining: 1h 12m 22s
# 105:	learn: 5.2914265	test: 5.2369510	best: 5.2369510 (105)	total: 58.4s	remaining: 1h 12m 28s
# 106:	learn: 5.2019049	test: 5.1489549	best: 5.1489549 (106)	total: 58.9s	remaining: 1h 12m 28s
# 107:	learn: 5.1140539	test: 5.0624851	best: 5.0624851 (107)	total: 59.7s	remaining: 1h 12m 39s
# 108:	learn: 5.0300159	test: 4.9799000	best: 4.9799000 (108)	total: 1m	remaining: 1h 12m 42s
# 109:	learn: 4.9488797	test: 4.9005496	best: 4.9005496 (109)	total: 1m	remaining: 1h 12m 41s
# 110:	learn: 4.8699879	test: 4.8236121	best: 4.8236121 (110)	total: 1m 1s	remaining: 1h 12m 37s
# 111:	learn: 4.7946513	test: 4.7495574	best: 4.7495574 (111)	total: 1m 1s	remaining: 1h 12m 45s
# 112:	learn: 4.7244591	test: 4.6812865	best: 4.6812865 (112)	total: 1m 2s	remaining: 1h 12m 40s
# 113:	learn: 4.6570312	test: 4.6156210	best: 4.6156210 (113)	total: 1m 3s	remaining: 1h 12m 38s
# 114:	learn: 4.5919449	test: 4.5521301	best: 4.5521301 (114)	total: 1m 3s	remaining: 1h 12m 39s
# 115:	learn: 4.5285192	test: 4.4906531	best: 4.4906531 (115)	total: 1m 4s	remaining: 1h 12m 42s
# 116:	learn: 4.4678704	test: 4.4319473	best: 4.4319473 (116)	total: 1m 4s	remaining: 1h 12m 36s
# 117:	learn: 4.4110998	test: 4.3771222	best: 4.3771222 (117)	total: 1m 5s	remaining: 1h 12m 36s
# 118:	learn: 4.3566137	test: 4.3250021	best: 4.3250021 (118)	total: 1m 5s	remaining: 1h 12m 32s
# 119:	learn: 4.3026441	test: 4.2726573	best: 4.2726573 (119)	total: 1m 6s	remaining: 1h 12m 34s
# 120:	learn: 4.2525386	test: 4.2245167	best: 4.2245167 (120)	total: 1m 6s	remaining: 1h 12m 30s
# 121:	learn: 4.2038821	test: 4.1781583	best: 4.1781583 (121)	total: 1m 7s	remaining: 1h 12m 34s
# 122:	learn: 4.1586810	test: 4.1348108	best: 4.1348108 (122)	total: 1m 7s	remaining: 1h 12m 29s
# 123:	learn: 4.1155332	test: 4.0936130	best: 4.0936130 (123)	total: 1m 8s	remaining: 1h 12m 32s
# 124:	learn: 4.0720087	test: 4.0519309	best: 4.0519309 (124)	total: 1m 9s	remaining: 1h 12m 32s
# 125:	learn: 4.0327457	test: 4.0143071	best: 4.0143071 (125)	total: 1m 9s	remaining: 1h 12m 32s
# 126:	learn: 3.9946145	test: 3.9771411	best: 3.9771411 (126)	total: 1m 10s	remaining: 1h 12m 35s
# 127:	learn: 3.9567467	test: 3.9412271	best: 3.9412271 (127)	total: 1m 10s	remaining: 1h 12m 37s
# 128:	learn: 3.9203973	test: 3.9067871	best: 3.9067871 (128)	total: 1m 11s	remaining: 1h 12m 33s
# 129:	learn: 3.8874183	test: 3.8757093	best: 3.8757093 (129)	total: 1m 11s	remaining: 1h 12m 29s
# 130:	learn: 3.8545554	test: 3.8441476	best: 3.8441476 (130)	total: 1m 12s	remaining: 1h 12m 35s
# 131:	learn: 3.8214327	test: 3.8126530	best: 3.8126530 (131)	total: 1m 13s	remaining: 1h 12m 35s
# 132:	learn: 3.7913552	test: 3.7843933	best: 3.7843933 (132)	total: 1m 13s	remaining: 1h 12m 36s
# 133:	learn: 3.7628584	test: 3.7573323	best: 3.7573323 (133)	total: 1m 14s	remaining: 1h 12m 37s
# 134:	learn: 3.7348477	test: 3.7308952	best: 3.7308952 (134)	total: 1m 14s	remaining: 1h 12m 44s
# 135:	learn: 3.7092305	test: 3.7069067	best: 3.7069067 (135)	total: 1m 15s	remaining: 1h 12m 46s
# 136:	learn: 3.6841221	test: 3.6831520	best: 3.6831520 (136)	total: 1m 16s	remaining: 1h 12m 49s
# 137:	learn: 3.6598167	test: 3.6605127	best: 3.6605127 (137)	total: 1m 16s	remaining: 1h 12m 45s
# 138:	learn: 3.6365948	test: 3.6386047	best: 3.6386047 (138)	total: 1m 17s	remaining: 1h 12m 42s
# 139:	learn: 3.6157683	test: 3.6193360	best: 3.6193360 (139)	total: 1m 17s	remaining: 1h 12m 42s
# 140:	learn: 3.5950408	test: 3.5999686	best: 3.5999686 (140)	total: 1m 18s	remaining: 1h 12m 39s
# 141:	learn: 3.5738961	test: 3.5802564	best: 3.5802564 (141)	total: 1m 18s	remaining: 1h 12m 35s
# 142:	learn: 3.5542637	test: 3.5622239	best: 3.5622239 (142)	total: 1m 19s	remaining: 1h 12m 31s
# 143:	learn: 3.5343513	test: 3.5442236	best: 3.5442236 (143)	total: 1m 19s	remaining: 1h 12m 34s
# 144:	learn: 3.5170751	test: 3.5288848	best: 3.5288848 (144)	total: 1m 20s	remaining: 1h 12m 35s
# 145:	learn: 3.4985673	test: 3.5113370	best: 3.5113370 (145)	total: 1m 21s	remaining: 1h 12m 41s
# 146:	learn: 3.4807668	test: 3.4950598	best: 3.4950598 (146)	total: 1m 21s	remaining: 1h 12m 39s
# 147:	learn: 3.4657577	test: 3.4804951	best: 3.4804951 (147)	total: 1m 22s	remaining: 1h 12m 41s
# 148:	learn: 3.4510686	test: 3.4668733	best: 3.4668733 (148)	total: 1m 22s	remaining: 1h 12m 39s
# 149:	learn: 3.4367366	test: 3.4534639	best: 3.4534639 (149)	total: 1m 23s	remaining: 1h 12m 42s
# 150:	learn: 3.4230208	test: 3.4410145	best: 3.4410145 (150)	total: 1m 23s	remaining: 1h 12m 38s
# 151:	learn: 3.4103197	test: 3.4292058	best: 3.4292058 (151)	total: 1m 24s	remaining: 1h 12m 39s
# 152:	learn: 3.3962348	test: 3.4159118	best: 3.4159118 (152)	total: 1m 24s	remaining: 1h 12m 36s
# 153:	learn: 3.3849848	test: 3.4056772	best: 3.4056772 (153)	total: 1m 25s	remaining: 1h 12m 38s
# 154:	learn: 3.3729324	test: 3.3948203	best: 3.3948203 (154)	total: 1m 26s	remaining: 1h 12m 40s
# 155:	learn: 3.3625721	test: 3.3850888	best: 3.3850888 (155)	total: 1m 26s	remaining: 1h 12m 42s
# 156:	learn: 3.3518095	test: 3.3751826	best: 3.3751826 (156)	total: 1m 27s	remaining: 1h 12m 42s
# 157:	learn: 3.3422854	test: 3.3667011	best: 3.3667011 (157)	total: 1m 27s	remaining: 1h 12m 41s
# 158:	learn: 3.3315320	test: 3.3572330	best: 3.3572330 (158)	total: 1m 28s	remaining: 1h 12m 40s
# 159:	learn: 3.3211157	test: 3.3474915	best: 3.3474915 (159)	total: 1m 28s	remaining: 1h 12m 37s
# 160:	learn: 3.3110454	test: 3.3381806	best: 3.3381806 (160)	total: 1m 29s	remaining: 1h 12m 33s
# 161:	learn: 3.3022825	test: 3.3304382	best: 3.3304382 (161)	total: 1m 29s	remaining: 1h 12m 33s
# 162:	learn: 3.2941945	test: 3.3233856	best: 3.3233856 (162)	total: 1m 30s	remaining: 1h 12m 32s
# 163:	learn: 3.2849604	test: 3.3148475	best: 3.3148475 (163)	total: 1m 31s	remaining: 1h 12m 38s
# 164:	learn: 3.2766015	test: 3.3075063	best: 3.3075063 (164)	total: 1m 31s	remaining: 1h 12m 38s
# 165:	learn: 3.2668682	test: 3.2989229	best: 3.2989229 (165)	total: 1m 32s	remaining: 1h 12m 38s
# 166:	learn: 3.2606704	test: 3.2939790	best: 3.2939790 (166)	total: 1m 32s	remaining: 1h 12m 38s
# 167:	learn: 3.2530829	test: 3.2875478	best: 3.2875478 (167)	total: 1m 33s	remaining: 1h 12m 38s
# 168:	learn: 3.2446724	test: 3.2797257	best: 3.2797257 (168)	total: 1m 34s	remaining: 1h 12m 40s
# 169:	learn: 3.2380404	test: 3.2736963	best: 3.2736963 (169)	total: 1m 34s	remaining: 1h 12m 36s
# 170:	learn: 3.2287120	test: 3.2651990	best: 3.2651990 (170)	total: 1m 35s	remaining: 1h 12m 35s
# 171:	learn: 3.2201708	test: 3.2576011	best: 3.2576011 (171)	total: 1m 35s	remaining: 1h 12m 37s
# 172:	learn: 3.2121628	test: 3.2503264	best: 3.2503264 (172)	total: 1m 36s	remaining: 1h 12m 42s
# 173:	learn: 3.2058049	test: 3.2445166	best: 3.2445166 (173)	total: 1m 37s	remaining: 1h 12m 43s
# 174:	learn: 3.1988546	test: 3.2376750	best: 3.2376750 (174)	total: 1m 37s	remaining: 1h 12m 46s
# 175:	learn: 3.1933410	test: 3.2329471	best: 3.2329471 (175)	total: 1m 38s	remaining: 1h 12m 47s
# 176:	learn: 3.1856984	test: 3.2259237	best: 3.2259237 (176)	total: 1m 38s	remaining: 1h 12m 48s
# 177:	learn: 3.1798333	test: 3.2202425	best: 3.2202425 (177)	total: 1m 39s	remaining: 1h 12m 49s
# 178:	learn: 3.1750123	test: 3.2159937	best: 3.2159937 (178)	total: 1m 40s	remaining: 1h 12m 51s
# 179:	learn: 3.1695133	test: 3.2111111	best: 3.2111111 (179)	total: 1m 40s	remaining: 1h 12m 49s
# 180:	learn: 3.1651672	test: 3.2074679	best: 3.2074679 (180)	total: 1m 41s	remaining: 1h 12m 48s
# 181:	learn: 3.1609491	test: 3.2042059	best: 3.2042059 (181)	total: 1m 41s	remaining: 1h 12m 50s
# 182:	learn: 3.1558109	test: 3.1990886	best: 3.1990886 (182)	total: 1m 42s	remaining: 1h 12m 50s
# 183:	learn: 3.1505466	test: 3.1947495	best: 3.1947495 (183)	total: 1m 42s	remaining: 1h 12m 52s
# 184:	learn: 3.1446735	test: 3.1897722	best: 3.1897722 (184)	total: 1m 43s	remaining: 1h 12m 53s
# 185:	learn: 3.1406647	test: 3.1864393	best: 3.1864393 (185)	total: 1m 44s	remaining: 1h 12m 52s
# 186:	learn: 3.1369427	test: 3.1833498	best: 3.1833498 (186)	total: 1m 44s	remaining: 1h 12m 50s
# 187:	learn: 3.1329651	test: 3.1797200	best: 3.1797200 (187)	total: 1m 45s	remaining: 1h 12m 52s
# 188:	learn: 3.1287485	test: 3.1758590	best: 3.1758590 (188)	total: 1m 45s	remaining: 1h 12m 54s
# 189:	learn: 3.1249230	test: 3.1722617	best: 3.1722617 (189)	total: 1m 46s	remaining: 1h 12m 53s
# 190:	learn: 3.1199419	test: 3.1677510	best: 3.1677510 (190)	total: 1m 46s	remaining: 1h 12m 50s
# 191:	learn: 3.1171318	test: 3.1653662	best: 3.1653662 (191)	total: 1m 47s	remaining: 1h 12m 46s
# 192:	learn: 3.1119643	test: 3.1610381	best: 3.1610381 (192)	total: 1m 47s	remaining: 1h 12m 46s
# 193:	learn: 3.1090725	test: 3.1588349	best: 3.1588349 (193)	total: 1m 48s	remaining: 1h 12m 44s
# 194:	learn: 3.1038184	test: 3.1543172	best: 3.1543172 (194)	total: 1m 49s	remaining: 1h 12m 43s
# 195:	learn: 3.0976164	test: 3.1490858	best: 3.1490858 (195)	total: 1m 49s	remaining: 1h 12m 40s
# 196:	learn: 3.0944264	test: 3.1463647	best: 3.1463647 (196)	total: 1m 50s	remaining: 1h 12m 37s
# 197:	learn: 3.0896139	test: 3.1419813	best: 3.1419813 (197)	total: 1m 50s	remaining: 1h 12m 38s
# 198:	learn: 3.0845916	test: 3.1372197	best: 3.1372197 (198)	total: 1m 51s	remaining: 1h 12m 38s
# 199:	learn: 3.0789450	test: 3.1321018	best: 3.1321018 (199)	total: 1m 51s	remaining: 1h 12m 40s
# 200:	learn: 3.0750250	test: 3.1285752	best: 3.1285752 (200)	total: 1m 52s	remaining: 1h 12m 39s
# 201:	learn: 3.0716644	test: 3.1258909	best: 3.1258909 (201)	total: 1m 52s	remaining: 1h 12m 35s
# 202:	learn: 3.0670173	test: 3.1216010	best: 3.1216010 (202)	total: 1m 53s	remaining: 1h 12m 37s
# 203:	learn: 3.0635431	test: 3.1183761	best: 3.1183761 (203)	total: 1m 54s	remaining: 1h 12m 39s
# 204:	learn: 3.0603202	test: 3.1153724	best: 3.1153724 (204)	total: 1m 54s	remaining: 1h 12m 40s
# 205:	learn: 3.0572348	test: 3.1131504	best: 3.1131504 (205)	total: 1m 55s	remaining: 1h 12m 42s
# 206:	learn: 3.0546816	test: 3.1110233	best: 3.1110233 (206)	total: 1m 55s	remaining: 1h 12m 40s
# 207:	learn: 3.0504186	test: 3.1073021	best: 3.1073021 (207)	total: 1m 56s	remaining: 1h 12m 44s
# 208:	learn: 3.0455334	test: 3.1022828	best: 3.1022828 (208)	total: 1m 57s	remaining: 1h 12m 47s
# 209:	learn: 3.0406398	test: 3.0978756	best: 3.0978756 (209)	total: 1m 57s	remaining: 1h 12m 47s
# 210:	learn: 3.0354033	test: 3.0928254	best: 3.0928254 (210)	total: 1m 58s	remaining: 1h 12m 46s
# 211:	learn: 3.0331239	test: 3.0905011	best: 3.0905011 (211)	total: 1m 58s	remaining: 1h 12m 44s
# 212:	learn: 3.0290889	test: 3.0872457	best: 3.0872457 (212)	total: 1m 59s	remaining: 1h 12m 43s
# 213:	learn: 3.0249011	test: 3.0830536	best: 3.0830536 (213)	total: 1m 59s	remaining: 1h 12m 44s
# 214:	learn: 3.0227864	test: 3.0818367	best: 3.0818367 (214)	total: 2m	remaining: 1h 12m 42s
# 215:	learn: 3.0193203	test: 3.0784122	best: 3.0784122 (215)	total: 2m 1s	remaining: 1h 12m 44s
# 216:	learn: 3.0168631	test: 3.0766157	best: 3.0766157 (216)	total: 2m 1s	remaining: 1h 12m 46s
# 217:	learn: 3.0134685	test: 3.0732019	best: 3.0732019 (217)	total: 2m 2s	remaining: 1h 12m 45s
# 218:	learn: 3.0108279	test: 3.0711727	best: 3.0711727 (218)	total: 2m 2s	remaining: 1h 12m 44s
# 219:	learn: 3.0072779	test: 3.0678250	best: 3.0678250 (219)	total: 2m 3s	remaining: 1h 12m 46s
# 220:	learn: 3.0037940	test: 3.0647494	best: 3.0647494 (220)	total: 2m 4s	remaining: 1h 12m 45s
# 221:	learn: 2.9993759	test: 3.0606226	best: 3.0606226 (221)	total: 2m 4s	remaining: 1h 12m 48s
# 222:	learn: 2.9961326	test: 3.0576586	best: 3.0576586 (222)	total: 2m 5s	remaining: 1h 12m 51s
# 223:	learn: 2.9926798	test: 3.0549018	best: 3.0549018 (223)	total: 2m 5s	remaining: 1h 12m 52s
# 224:	learn: 2.9889899	test: 3.0513116	best: 3.0513116 (224)	total: 2m 6s	remaining: 1h 12m 51s
# 225:	learn: 2.9854818	test: 3.0484458	best: 3.0484458 (225)	total: 2m 7s	remaining: 1h 12m 54s
# 226:	learn: 2.9825169	test: 3.0458693	best: 3.0458693 (226)	total: 2m 7s	remaining: 1h 12m 53s
# 227:	learn: 2.9808012	test: 3.0445904	best: 3.0445904 (227)	total: 2m 8s	remaining: 1h 12m 52s
# 228:	learn: 2.9789078	test: 3.0428417	best: 3.0428417 (228)	total: 2m 8s	remaining: 1h 12m 55s
# 229:	learn: 2.9756768	test: 3.0399410	best: 3.0399410 (229)	total: 2m 9s	remaining: 1h 12m 54s
# 230:	learn: 2.9734628	test: 3.0382493	best: 3.0382493 (230)	total: 2m 10s	remaining: 1h 12m 52s
# 231:	learn: 2.9710476	test: 3.0363094	best: 3.0363094 (231)	total: 2m 10s	remaining: 1h 12m 51s
# 232:	learn: 2.9667313	test: 3.0325588	best: 3.0325588 (232)	total: 2m 11s	remaining: 1h 12m 49s
# 233:	learn: 2.9648032	test: 3.0310187	best: 3.0310187 (233)	total: 2m 11s	remaining: 1h 12m 50s
# 234:	learn: 2.9590793	test: 3.0260779	best: 3.0260779 (234)	total: 2m 12s	remaining: 1h 12m 50s
# 235:	learn: 2.9545160	test: 3.0221124	best: 3.0221124 (235)	total: 2m 12s	remaining: 1h 12m 50s
# 236:	learn: 2.9517920	test: 3.0196685	best: 3.0196685 (236)	total: 2m 13s	remaining: 1h 12m 49s
# 237:	learn: 2.9485490	test: 3.0172283	best: 3.0172283 (237)	total: 2m 13s	remaining: 1h 12m 49s
# 238:	learn: 2.9440902	test: 3.0134155	best: 3.0134155 (238)	total: 2m 14s	remaining: 1h 12m 49s
# 239:	learn: 2.9409091	test: 3.0102461	best: 3.0102461 (239)	total: 2m 15s	remaining: 1h 12m 48s
# 240:	learn: 2.9382794	test: 3.0079420	best: 3.0079420 (240)	total: 2m 15s	remaining: 1h 12m 47s
# 241:	learn: 2.9345186	test: 3.0044853	best: 3.0044853 (241)	total: 2m 16s	remaining: 1h 12m 47s
# 242:	learn: 2.9312387	test: 3.0018729	best: 3.0018729 (242)	total: 2m 16s	remaining: 1h 12m 47s
# 243:	learn: 2.9288118	test: 3.0000142	best: 3.0000142 (243)	total: 2m 17s	remaining: 1h 12m 47s
# 244:	learn: 2.9254850	test: 2.9968388	best: 2.9968388 (244)	total: 2m 17s	remaining: 1h 12m 47s
# 245:	learn: 2.9214225	test: 2.9931814	best: 2.9931814 (245)	total: 2m 18s	remaining: 1h 12m 47s
# 246:	learn: 2.9188343	test: 2.9910612	best: 2.9910612 (246)	total: 2m 19s	remaining: 1h 12m 48s
# 247:	learn: 2.9151599	test: 2.9878849	best: 2.9878849 (247)	total: 2m 19s	remaining: 1h 12m 48s
# 248:	learn: 2.9126050	test: 2.9854351	best: 2.9854351 (248)	total: 2m 20s	remaining: 1h 12m 49s
# 249:	learn: 2.9105011	test: 2.9836455	best: 2.9836455 (249)	total: 2m 20s	remaining: 1h 12m 50s
# 250:	learn: 2.9069696	test: 2.9804490	best: 2.9804490 (250)	total: 2m 21s	remaining: 1h 12m 47s
# 251:	learn: 2.9040814	test: 2.9778550	best: 2.9778550 (251)	total: 2m 22s	remaining: 1h 12m 49s
# 252:	learn: 2.9014670	test: 2.9755562	best: 2.9755562 (252)	total: 2m 22s	remaining: 1h 12m 48s
# 253:	learn: 2.8992879	test: 2.9734876	best: 2.9734876 (253)	total: 2m 23s	remaining: 1h 12m 48s
# 254:	learn: 2.8967509	test: 2.9715341	best: 2.9715341 (254)	total: 2m 23s	remaining: 1h 12m 47s
# 255:	learn: 2.8933079	test: 2.9684504	best: 2.9684504 (255)	total: 2m 24s	remaining: 1h 12m 49s
# 256:	learn: 2.8911586	test: 2.9665165	best: 2.9665165 (256)	total: 2m 25s	remaining: 1h 12m 48s
# 257:	learn: 2.8875618	test: 2.9632361	best: 2.9632361 (257)	total: 2m 25s	remaining: 1h 12m 46s
# 258:	learn: 2.8846409	test: 2.9604024	best: 2.9604024 (258)	total: 2m 26s	remaining: 1h 12m 46s
# 259:	learn: 2.8810326	test: 2.9576080	best: 2.9576080 (259)	total: 2m 26s	remaining: 1h 12m 46s
# 260:	learn: 2.8785551	test: 2.9554488	best: 2.9554488 (260)	total: 2m 27s	remaining: 1h 12m 47s
# 261:	learn: 2.8757612	test: 2.9530520	best: 2.9530520 (261)	total: 2m 27s	remaining: 1h 12m 48s
# 262:	learn: 2.8732569	test: 2.9508240	best: 2.9508240 (262)	total: 2m 28s	remaining: 1h 12m 49s
# 263:	learn: 2.8695046	test: 2.9474189	best: 2.9474189 (263)	total: 2m 29s	remaining: 1h 12m 46s
# 264:	learn: 2.8664805	test: 2.9445635	best: 2.9445635 (264)	total: 2m 29s	remaining: 1h 12m 49s
# 265:	learn: 2.8639586	test: 2.9424794	best: 2.9424794 (265)	total: 2m 30s	remaining: 1h 12m 50s
# 266:	learn: 2.8600138	test: 2.9393264	best: 2.9393264 (266)	total: 2m 30s	remaining: 1h 12m 49s
# 267:	learn: 2.8574915	test: 2.9369164	best: 2.9369164 (267)	total: 2m 31s	remaining: 1h 12m 50s
# 268:	learn: 2.8539430	test: 2.9339539	best: 2.9339539 (268)	total: 2m 32s	remaining: 1h 12m 51s
# 269:	learn: 2.8503504	test: 2.9307834	best: 2.9307834 (269)	total: 2m 32s	remaining: 1h 12m 50s
# 270:	learn: 2.8488840	test: 2.9299642	best: 2.9299642 (270)	total: 2m 33s	remaining: 1h 12m 48s
# 271:	learn: 2.8456784	test: 2.9268791	best: 2.9268791 (271)	total: 2m 33s	remaining: 1h 12m 48s
# 272:	learn: 2.8431719	test: 2.9247952	best: 2.9247952 (272)	total: 2m 34s	remaining: 1h 12m 49s
# 273:	learn: 2.8416276	test: 2.9235611	best: 2.9235611 (273)	total: 2m 34s	remaining: 1h 12m 48s
# 274:	learn: 2.8385080	test: 2.9206801	best: 2.9206801 (274)	total: 2m 35s	remaining: 1h 12m 48s
# 275:	learn: 2.8361252	test: 2.9187640	best: 2.9187640 (275)	total: 2m 36s	remaining: 1h 12m 47s
# 276:	learn: 2.8339087	test: 2.9169518	best: 2.9169518 (276)	total: 2m 36s	remaining: 1h 12m 47s
# 277:	learn: 2.8308356	test: 2.9146210	best: 2.9146210 (277)	total: 2m 37s	remaining: 1h 12m 47s
# 278:	learn: 2.8281119	test: 2.9122421	best: 2.9122421 (278)	total: 2m 37s	remaining: 1h 12m 46s
# 279:	learn: 2.8254949	test: 2.9100260	best: 2.9100260 (279)	total: 2m 38s	remaining: 1h 12m 47s
# 280:	learn: 2.8221006	test: 2.9072421	best: 2.9072421 (280)	total: 2m 38s	remaining: 1h 12m 47s
# 281:	learn: 2.8202356	test: 2.9054565	best: 2.9054565 (281)	total: 2m 39s	remaining: 1h 12m 46s
# 282:	learn: 2.8185173	test: 2.9041229	best: 2.9041229 (282)	total: 2m 40s	remaining: 1h 12m 46s
# 283:	learn: 2.8156824	test: 2.9016610	best: 2.9016610 (283)	total: 2m 40s	remaining: 1h 12m 48s
# 284:	learn: 2.8136847	test: 2.8999173	best: 2.8999173 (284)	total: 2m 41s	remaining: 1h 12m 47s
# 285:	learn: 2.8099973	test: 2.8957498	best: 2.8957498 (285)	total: 2m 41s	remaining: 1h 12m 45s
# 286:	learn: 2.8072910	test: 2.8938461	best: 2.8938461 (286)	total: 2m 42s	remaining: 1h 12m 46s
# 287:	learn: 2.8042103	test: 2.8911240	best: 2.8911240 (287)	total: 2m 43s	remaining: 1h 12m 47s
# 288:	learn: 2.8008469	test: 2.8878556	best: 2.8878556 (288)	total: 2m 43s	remaining: 1h 12m 45s
# 289:	learn: 2.7994735	test: 2.8867474	best: 2.8867474 (289)	total: 2m 44s	remaining: 1h 12m 44s
# 290:	learn: 2.7973739	test: 2.8845892	best: 2.8845892 (290)	total: 2m 44s	remaining: 1h 12m 42s
# 291:	learn: 2.7954053	test: 2.8828747	best: 2.8828747 (291)	total: 2m 45s	remaining: 1h 12m 41s
# 292:	learn: 2.7935387	test: 2.8812020	best: 2.8812020 (292)	total: 2m 45s	remaining: 1h 12m 41s
# 293:	learn: 2.7911161	test: 2.8792354	best: 2.8792354 (293)	total: 2m 46s	remaining: 1h 12m 42s
# 294:	learn: 2.7895637	test: 2.8782857	best: 2.8782857 (294)	total: 2m 47s	remaining: 1h 12m 41s
# 295:	learn: 2.7873095	test: 2.8762072	best: 2.8762072 (295)	total: 2m 47s	remaining: 1h 12m 41s
# 296:	learn: 2.7847109	test: 2.8740287	best: 2.8740287 (296)	total: 2m 48s	remaining: 1h 12m 40s
# 297:	learn: 2.7823539	test: 2.8721763	best: 2.8721763 (297)	total: 2m 48s	remaining: 1h 12m 39s
# 298:	learn: 2.7810919	test: 2.8710737	best: 2.8710737 (298)	total: 2m 49s	remaining: 1h 12m 38s
# 299:	learn: 2.7793031	test: 2.8690739	best: 2.8690739 (299)	total: 2m 49s	remaining: 1h 12m 39s
# 300:	learn: 2.7773365	test: 2.8675712	best: 2.8675712 (300)	total: 2m 50s	remaining: 1h 12m 39s
# 301:	learn: 2.7745407	test: 2.8653612	best: 2.8653612 (301)	total: 2m 51s	remaining: 1h 12m 39s
# 302:	learn: 2.7726444	test: 2.8637566	best: 2.8637566 (302)	total: 2m 51s	remaining: 1h 12m 40s
# 303:	learn: 2.7702540	test: 2.8615231	best: 2.8615231 (303)	total: 2m 52s	remaining: 1h 12m 39s
# 304:	learn: 2.7680089	test: 2.8599349	best: 2.8599349 (304)	total: 2m 52s	remaining: 1h 12m 38s
# 305:	learn: 2.7653045	test: 2.8573667	best: 2.8573667 (305)	total: 2m 53s	remaining: 1h 12m 38s
# 306:	learn: 2.7629392	test: 2.8554415	best: 2.8554415 (306)	total: 2m 53s	remaining: 1h 12m 38s
# 307:	learn: 2.7610180	test: 2.8542618	best: 2.8542618 (307)	total: 2m 54s	remaining: 1h 12m 37s
# 308:	learn: 2.7590268	test: 2.8524493	best: 2.8524493 (308)	total: 2m 55s	remaining: 1h 12m 36s
# 309:	learn: 2.7556869	test: 2.8495020	best: 2.8495020 (309)	total: 2m 55s	remaining: 1h 12m 35s
# 310:	learn: 2.7540646	test: 2.8481822	best: 2.8481822 (310)	total: 2m 56s	remaining: 1h 12m 32s
# 311:	learn: 2.7513175	test: 2.8455994	best: 2.8455994 (311)	total: 2m 56s	remaining: 1h 12m 31s
# 312:	learn: 2.7489739	test: 2.8437521	best: 2.8437521 (312)	total: 2m 57s	remaining: 1h 12m 32s
# 313:	learn: 2.7473992	test: 2.8424655	best: 2.8424655 (313)	total: 2m 57s	remaining: 1h 12m 30s
# 314:	learn: 2.7449859	test: 2.8400836	best: 2.8400836 (314)	total: 2m 58s	remaining: 1h 12m 32s
# 315:	learn: 2.7432293	test: 2.8388065	best: 2.8388065 (315)	total: 2m 58s	remaining: 1h 12m 31s
# 316:	learn: 2.7406461	test: 2.8364535	best: 2.8364535 (316)	total: 2m 59s	remaining: 1h 12m 29s
# 317:	learn: 2.7389721	test: 2.8351697	best: 2.8351697 (317)	total: 3m	remaining: 1h 12m 31s
# 318:	learn: 2.7361119	test: 2.8326112	best: 2.8326112 (318)	total: 3m	remaining: 1h 12m 31s
# 319:	learn: 2.7336798	test: 2.8306584	best: 2.8306584 (319)	total: 3m 1s	remaining: 1h 12m 30s
# 320:	learn: 2.7316108	test: 2.8284802	best: 2.8284802 (320)	total: 3m 1s	remaining: 1h 12m 32s
# 321:	learn: 2.7286342	test: 2.8259736	best: 2.8259736 (321)	total: 3m 2s	remaining: 1h 12m 34s
# 322:	learn: 2.7275863	test: 2.8250701	best: 2.8250701 (322)	total: 3m 3s	remaining: 1h 12m 33s
# 323:	learn: 2.7264939	test: 2.8241063	best: 2.8241063 (323)	total: 3m 3s	remaining: 1h 12m 32s
# 324:	learn: 2.7228793	test: 2.8211588	best: 2.8211588 (324)	total: 3m 4s	remaining: 1h 12m 31s
# 325:	learn: 2.7206128	test: 2.8192666	best: 2.8192666 (325)	total: 3m 4s	remaining: 1h 12m 33s
# 326:	learn: 2.7189234	test: 2.8178789	best: 2.8178789 (326)	total: 3m 5s	remaining: 1h 12m 33s
# 327:	learn: 2.7167232	test: 2.8162709	best: 2.8162709 (327)	total: 3m 6s	remaining: 1h 12m 32s
# 328:	learn: 2.7150973	test: 2.8148375	best: 2.8148375 (328)	total: 3m 6s	remaining: 1h 12m 31s
# 329:	learn: 2.7124899	test: 2.8121119	best: 2.8121119 (329)	total: 3m 7s	remaining: 1h 12m 32s
# 330:	learn: 2.7107082	test: 2.8105941	best: 2.8105941 (330)	total: 3m 7s	remaining: 1h 12m 31s
# 331:	learn: 2.7094025	test: 2.8096112	best: 2.8096112 (331)	total: 3m 8s	remaining: 1h 12m 30s
# 332:	learn: 2.7063670	test: 2.8073557	best: 2.8073557 (332)	total: 3m 8s	remaining: 1h 12m 30s
# 333:	learn: 2.7038169	test: 2.8052189	best: 2.8052189 (333)	total: 3m 9s	remaining: 1h 12m 31s
# 334:	learn: 2.7013631	test: 2.8033767	best: 2.8033767 (334)	total: 3m 10s	remaining: 1h 12m 31s
# 335:	learn: 2.6986444	test: 2.8012027	best: 2.8012027 (335)	total: 3m 10s	remaining: 1h 12m 30s
# 336:	learn: 2.6965040	test: 2.7995561	best: 2.7995561 (336)	total: 3m 11s	remaining: 1h 12m 30s
# 337:	learn: 2.6942370	test: 2.7978266	best: 2.7978266 (337)	total: 3m 11s	remaining: 1h 12m 31s
# 338:	learn: 2.6918234	test: 2.7957859	best: 2.7957859 (338)	total: 3m 12s	remaining: 1h 12m 29s
# 339:	learn: 2.6895234	test: 2.7939756	best: 2.7939756 (339)	total: 3m 13s	remaining: 1h 12m 29s
# 340:	learn: 2.6874224	test: 2.7926063	best: 2.7926063 (340)	total: 3m 13s	remaining: 1h 12m 30s
# 341:	learn: 2.6856616	test: 2.7911177	best: 2.7911177 (341)	total: 3m 14s	remaining: 1h 12m 29s
# 342:	learn: 2.6827695	test: 2.7884006	best: 2.7884006 (342)	total: 3m 14s	remaining: 1h 12m 29s
# 343:	learn: 2.6810732	test: 2.7870824	best: 2.7870824 (343)	total: 3m 15s	remaining: 1h 12m 27s
# 344:	learn: 2.6790055	test: 2.7855033	best: 2.7855033 (344)	total: 3m 15s	remaining: 1h 12m 27s
# 345:	learn: 2.6770337	test: 2.7838837	best: 2.7838837 (345)	total: 3m 16s	remaining: 1h 12m 26s
# 346:	learn: 2.6749565	test: 2.7823973	best: 2.7823973 (346)	total: 3m 17s	remaining: 1h 12m 25s
# 347:	learn: 2.6727551	test: 2.7802371	best: 2.7802371 (347)	total: 3m 17s	remaining: 1h 12m 25s
# 348:	learn: 2.6711684	test: 2.7787337	best: 2.7787337 (348)	total: 3m 18s	remaining: 1h 12m 24s
# 349:	learn: 2.6698341	test: 2.7776388	best: 2.7776388 (349)	total: 3m 18s	remaining: 1h 12m 24s
# 350:	learn: 2.6676908	test: 2.7761724	best: 2.7761724 (350)	total: 3m 19s	remaining: 1h 12m 22s
# 351:	learn: 2.6649621	test: 2.7740370	best: 2.7740370 (351)	total: 3m 19s	remaining: 1h 12m 21s
# 352:	learn: 2.6636391	test: 2.7730840	best: 2.7730840 (352)	total: 3m 20s	remaining: 1h 12m 20s
# 353:	learn: 2.6619837	test: 2.7715073	best: 2.7715073 (353)	total: 3m 20s	remaining: 1h 12m 19s
# 354:	learn: 2.6599706	test: 2.7698324	best: 2.7698324 (354)	total: 3m 21s	remaining: 1h 12m 21s
# 355:	learn: 2.6585339	test: 2.7685669	best: 2.7685669 (355)	total: 3m 22s	remaining: 1h 12m 20s
# 356:	learn: 2.6567511	test: 2.7671722	best: 2.7671722 (356)	total: 3m 22s	remaining: 1h 12m 17s
# 357:	learn: 2.6548972	test: 2.7654453	best: 2.7654453 (357)	total: 3m 23s	remaining: 1h 12m 18s
# 358:	learn: 2.6528578	test: 2.7639377	best: 2.7639377 (358)	total: 3m 23s	remaining: 1h 12m 17s
# 359:	learn: 2.6502666	test: 2.7616918	best: 2.7616918 (359)	total: 3m 24s	remaining: 1h 12m 17s
# 360:	learn: 2.6479654	test: 2.7597980	best: 2.7597980 (360)	total: 3m 25s	remaining: 1h 12m 18s
# 361:	learn: 2.6458316	test: 2.7579558	best: 2.7579558 (361)	total: 3m 25s	remaining: 1h 12m 17s
# 362:	learn: 2.6433444	test: 2.7561137	best: 2.7561137 (362)	total: 3m 26s	remaining: 1h 12m 17s
# 363:	learn: 2.6416868	test: 2.7548669	best: 2.7548669 (363)	total: 3m 26s	remaining: 1h 12m 17s
# 364:	learn: 2.6393525	test: 2.7527737	best: 2.7527737 (364)	total: 3m 27s	remaining: 1h 12m 17s
# 365:	learn: 2.6378869	test: 2.7516307	best: 2.7516307 (365)	total: 3m 28s	remaining: 1h 12m 19s
# 366:	learn: 2.6355098	test: 2.7498010	best: 2.7498010 (366)	total: 3m 28s	remaining: 1h 12m 17s
# 367:	learn: 2.6337352	test: 2.7483251	best: 2.7483251 (367)	total: 3m 29s	remaining: 1h 12m 18s
# 368:	learn: 2.6319963	test: 2.7465730	best: 2.7465730 (368)	total: 3m 29s	remaining: 1h 12m 17s
# 369:	learn: 2.6304172	test: 2.7452620	best: 2.7452620 (369)	total: 3m 30s	remaining: 1h 12m 17s
# 370:	learn: 2.6283214	test: 2.7432117	best: 2.7432117 (370)	total: 3m 30s	remaining: 1h 12m 18s
# 371:	learn: 2.6259686	test: 2.7411806	best: 2.7411806 (371)	total: 3m 31s	remaining: 1h 12m 18s
# 372:	learn: 2.6246954	test: 2.7400457	best: 2.7400457 (372)	total: 3m 32s	remaining: 1h 12m 16s
# 373:	learn: 2.6235889	test: 2.7391773	best: 2.7391773 (373)	total: 3m 32s	remaining: 1h 12m 15s
# 374:	learn: 2.6213950	test: 2.7372474	best: 2.7372474 (374)	total: 3m 33s	remaining: 1h 12m 14s
# 375:	learn: 2.6196271	test: 2.7357006	best: 2.7357006 (375)	total: 3m 33s	remaining: 1h 12m 13s
# 376:	learn: 2.6170820	test: 2.7337032	best: 2.7337032 (376)	total: 3m 34s	remaining: 1h 12m 13s
# 377:	learn: 2.6158887	test: 2.7327026	best: 2.7327026 (377)	total: 3m 34s	remaining: 1h 12m 11s
# 378:	learn: 2.6141489	test: 2.7311728	best: 2.7311728 (378)	total: 3m 35s	remaining: 1h 12m 10s
# 379:	learn: 2.6122488	test: 2.7295864	best: 2.7295864 (379)	total: 3m 36s	remaining: 1h 12m 11s
# 380:	learn: 2.6101918	test: 2.7281190	best: 2.7281190 (380)	total: 3m 36s	remaining: 1h 12m 10s
# 381:	learn: 2.6085672	test: 2.7267037	best: 2.7267037 (381)	total: 3m 37s	remaining: 1h 12m 10s
# 382:	learn: 2.6070300	test: 2.7252924	best: 2.7252924 (382)	total: 3m 37s	remaining: 1h 12m 10s
# 383:	learn: 2.6054902	test: 2.7240964	best: 2.7240964 (383)	total: 3m 38s	remaining: 1h 12m 9s
# 384:	learn: 2.6045562	test: 2.7233526	best: 2.7233526 (384)	total: 3m 38s	remaining: 1h 12m 8s
# 385:	learn: 2.6033341	test: 2.7222500	best: 2.7222500 (385)	total: 3m 39s	remaining: 1h 12m 8s
# 386:	learn: 2.6019046	test: 2.7209354	best: 2.7209354 (386)	total: 3m 39s	remaining: 1h 12m 6s
# 387:	learn: 2.5992678	test: 2.7186458	best: 2.7186458 (387)	total: 3m 40s	remaining: 1h 12m 7s
# 388:	learn: 2.5966417	test: 2.7166480	best: 2.7166480 (388)	total: 3m 41s	remaining: 1h 12m 7s
# 389:	learn: 2.5947335	test: 2.7151591	best: 2.7151591 (389)	total: 3m 41s	remaining: 1h 12m 7s
# 390:	learn: 2.5926019	test: 2.7133004	best: 2.7133004 (390)	total: 3m 42s	remaining: 1h 12m 5s
# 391:	learn: 2.5916331	test: 2.7126570	best: 2.7126570 (391)	total: 3m 42s	remaining: 1h 12m 5s
# 392:	learn: 2.5890176	test: 2.7105273	best: 2.7105273 (392)	total: 3m 43s	remaining: 1h 12m 5s
# 393:	learn: 2.5870822	test: 2.7088758	best: 2.7088758 (393)	total: 3m 44s	remaining: 1h 12m 4s
# 394:	learn: 2.5851950	test: 2.7071356	best: 2.7071356 (394)	total: 3m 44s	remaining: 1h 12m 5s
# 395:	learn: 2.5832526	test: 2.7055126	best: 2.7055126 (395)	total: 3m 45s	remaining: 1h 12m 5s
# 396:	learn: 2.5815168	test: 2.7041066	best: 2.7041066 (396)	total: 3m 45s	remaining: 1h 12m 5s
# 397:	learn: 2.5791577	test: 2.7021025	best: 2.7021025 (397)	total: 3m 46s	remaining: 1h 12m 4s
# 398:	learn: 2.5769189	test: 2.7002489	best: 2.7002489 (398)	total: 3m 47s	remaining: 1h 12m 4s
# 399:	learn: 2.5747027	test: 2.6982580	best: 2.6982580 (399)	total: 3m 47s	remaining: 1h 12m 5s
# 400:	learn: 2.5733214	test: 2.6971165	best: 2.6971165 (400)	total: 3m 48s	remaining: 1h 12m 4s
# 401:	learn: 2.5723461	test: 2.6963337	best: 2.6963337 (401)	total: 3m 48s	remaining: 1h 12m 3s
# 402:	learn: 2.5708971	test: 2.6954011	best: 2.6954011 (402)	total: 3m 49s	remaining: 1h 12m 2s
# 403:	learn: 2.5691440	test: 2.6936730	best: 2.6936730 (403)	total: 3m 49s	remaining: 1h 12m 1s
# 404:	learn: 2.5676289	test: 2.6923259	best: 2.6923259 (404)	total: 3m 50s	remaining: 1h 12m
# 405:	learn: 2.5662515	test: 2.6912627	best: 2.6912627 (405)	total: 3m 50s	remaining: 1h 12m
# 406:	learn: 2.5642722	test: 2.6895153	best: 2.6895153 (406)	total: 3m 51s	remaining: 1h 11m 59s
# 407:	learn: 2.5630832	test: 2.6884641	best: 2.6884641 (407)	total: 3m 52s	remaining: 1h 11m 58s
# 408:	learn: 2.5603224	test: 2.6863702	best: 2.6863702 (408)	total: 3m 52s	remaining: 1h 11m 58s
# 409:	learn: 2.5584056	test: 2.6850088	best: 2.6850088 (409)	total: 3m 53s	remaining: 1h 11m 59s
# 410:	learn: 2.5568635	test: 2.6835128	best: 2.6835128 (410)	total: 3m 53s	remaining: 1h 11m 59s
# 411:	learn: 2.5554964	test: 2.6823454	best: 2.6823454 (411)	total: 3m 54s	remaining: 1h 11m 58s
# 412:	learn: 2.5536951	test: 2.6808046	best: 2.6808046 (412)	total: 3m 54s	remaining: 1h 11m 56s
# 413:	learn: 2.5524897	test: 2.6799858	best: 2.6799858 (413)	total: 3m 55s	remaining: 1h 11m 56s
# 414:	learn: 2.5505017	test: 2.6782061	best: 2.6782061 (414)	total: 3m 56s	remaining: 1h 11m 55s
# 415:	learn: 2.5492169	test: 2.6770194	best: 2.6770194 (415)	total: 3m 56s	remaining: 1h 11m 53s
# 416:	learn: 2.5479688	test: 2.6761476	best: 2.6761476 (416)	total: 3m 57s	remaining: 1h 11m 52s
# 417:	learn: 2.5463398	test: 2.6749578	best: 2.6749578 (417)	total: 3m 57s	remaining: 1h 11m 51s
# 418:	learn: 2.5446697	test: 2.6737563	best: 2.6737563 (418)	total: 3m 58s	remaining: 1h 11m 51s
# 419:	learn: 2.5424393	test: 2.6719912	best: 2.6719912 (419)	total: 3m 58s	remaining: 1h 11m 51s
# 420:	learn: 2.5401205	test: 2.6701527	best: 2.6701527 (420)	total: 3m 59s	remaining: 1h 11m 51s
# 421:	learn: 2.5386442	test: 2.6689189	best: 2.6689189 (421)	total: 4m	remaining: 1h 11m 50s
# 422:	learn: 2.5366959	test: 2.6673509	best: 2.6673509 (422)	total: 4m	remaining: 1h 11m 51s
# 423:	learn: 2.5349458	test: 2.6659132	best: 2.6659132 (423)	total: 4m 1s	remaining: 1h 11m 52s
# 424:	learn: 2.5325868	test: 2.6638619	best: 2.6638619 (424)	total: 4m 1s	remaining: 1h 11m 52s
# 425:	learn: 2.5310780	test: 2.6626827	best: 2.6626827 (425)	total: 4m 2s	remaining: 1h 11m 53s
# 426:	learn: 2.5301076	test: 2.6619358	best: 2.6619358 (426)	total: 4m 3s	remaining: 1h 11m 52s
# 427:	learn: 2.5281610	test: 2.6602062	best: 2.6602062 (427)	total: 4m 3s	remaining: 1h 11m 50s
# 428:	learn: 2.5269349	test: 2.6594175	best: 2.6594175 (428)	total: 4m 4s	remaining: 1h 11m 49s
# 429:	learn: 2.5256667	test: 2.6583077	best: 2.6583077 (429)	total: 4m 4s	remaining: 1h 11m 49s
# 430:	learn: 2.5238994	test: 2.6573419	best: 2.6573419 (430)	total: 4m 5s	remaining: 1h 11m 48s
# 431:	learn: 2.5223676	test: 2.6560300	best: 2.6560300 (431)	total: 4m 5s	remaining: 1h 11m 47s
# 432:	learn: 2.5204670	test: 2.6543456	best: 2.6543456 (432)	total: 4m 6s	remaining: 1h 11m 47s
# 433:	learn: 2.5186232	test: 2.6531349	best: 2.6531349 (433)	total: 4m 7s	remaining: 1h 11m 47s
# 434:	learn: 2.5171632	test: 2.6520907	best: 2.6520907 (434)	total: 4m 7s	remaining: 1h 11m 47s
# 435:	learn: 2.5159506	test: 2.6512555	best: 2.6512555 (435)	total: 4m 8s	remaining: 1h 11m 47s
# 436:	learn: 2.5142413	test: 2.6499944	best: 2.6499944 (436)	total: 4m 8s	remaining: 1h 11m 46s
# 437:	learn: 2.5120219	test: 2.6481836	best: 2.6481836 (437)	total: 4m 9s	remaining: 1h 11m 45s
# 438:	learn: 2.5097945	test: 2.6463551	best: 2.6463551 (438)	total: 4m 9s	remaining: 1h 11m 45s
# 439:	learn: 2.5087041	test: 2.6454271	best: 2.6454271 (439)	total: 4m 10s	remaining: 1h 11m 44s
# 440:	learn: 2.5072428	test: 2.6442703	best: 2.6442703 (440)	total: 4m 11s	remaining: 1h 11m 43s
# 441:	learn: 2.5054852	test: 2.6430302	best: 2.6430302 (441)	total: 4m 11s	remaining: 1h 11m 42s
# 442:	learn: 2.5039924	test: 2.6419512	best: 2.6419512 (442)	total: 4m 12s	remaining: 1h 11m 42s
# 443:	learn: 2.5028075	test: 2.6409656	best: 2.6409656 (443)	total: 4m 12s	remaining: 1h 11m 42s
# 444:	learn: 2.5006112	test: 2.6392413	best: 2.6392413 (444)	total: 4m 13s	remaining: 1h 11m 41s
# 445:	learn: 2.4992873	test: 2.6381766	best: 2.6381766 (445)	total: 4m 14s	remaining: 1h 11m 42s
# 446:	learn: 2.4980333	test: 2.6373460	best: 2.6373460 (446)	total: 4m 14s	remaining: 1h 11m 40s
# 447:	learn: 2.4970518	test: 2.6364413	best: 2.6364413 (447)	total: 4m 15s	remaining: 1h 11m 41s
# 448:	learn: 2.4957162	test: 2.6354530	best: 2.6354530 (448)	total: 4m 15s	remaining: 1h 11m 40s
# 449:	learn: 2.4946492	test: 2.6346643	best: 2.6346643 (449)	total: 4m 16s	remaining: 1h 11m 38s
# 450:	learn: 2.4929840	test: 2.6334775	best: 2.6334775 (450)	total: 4m 16s	remaining: 1h 11m 38s
# 451:	learn: 2.4915898	test: 2.6324019	best: 2.6324019 (451)	total: 4m 17s	remaining: 1h 11m 37s
# 452:	learn: 2.4903303	test: 2.6312721	best: 2.6312721 (452)	total: 4m 17s	remaining: 1h 11m 36s
# 453:	learn: 2.4886524	test: 2.6298421	best: 2.6298421 (453)	total: 4m 18s	remaining: 1h 11m 36s
# 454:	learn: 2.4872511	test: 2.6285817	best: 2.6285817 (454)	total: 4m 19s	remaining: 1h 11m 36s
# 455:	learn: 2.4849756	test: 2.6271167	best: 2.6271167 (455)	total: 4m 19s	remaining: 1h 11m 36s
# 456:	learn: 2.4830724	test: 2.6255666	best: 2.6255666 (456)	total: 4m 20s	remaining: 1h 11m 36s
# 457:	learn: 2.4820061	test: 2.6245315	best: 2.6245315 (457)	total: 4m 20s	remaining: 1h 11m 36s
# 458:	learn: 2.4798766	test: 2.6229363	best: 2.6229363 (458)	total: 4m 21s	remaining: 1h 11m 35s
# 459:	learn: 2.4786453	test: 2.6220068	best: 2.6220068 (459)	total: 4m 22s	remaining: 1h 11m 36s
# 460:	learn: 2.4769250	test: 2.6205464	best: 2.6205464 (460)	total: 4m 22s	remaining: 1h 11m 35s
# 461:	learn: 2.4752060	test: 2.6191758	best: 2.6191758 (461)	total: 4m 23s	remaining: 1h 11m 35s
# 462:	learn: 2.4729814	test: 2.6175401	best: 2.6175401 (462)	total: 4m 23s	remaining: 1h 11m 34s
# 463:	learn: 2.4721543	test: 2.6169721	best: 2.6169721 (463)	total: 4m 24s	remaining: 1h 11m 33s
# 464:	learn: 2.4708971	test: 2.6161331	best: 2.6161331 (464)	total: 4m 24s	remaining: 1h 11m 32s
# 465:	learn: 2.4693728	test: 2.6149983	best: 2.6149983 (465)	total: 4m 25s	remaining: 1h 11m 31s
# 466:	learn: 2.4678916	test: 2.6138845	best: 2.6138845 (466)	total: 4m 25s	remaining: 1h 11m 30s
# 467:	learn: 2.4661428	test: 2.6126247	best: 2.6126247 (467)	total: 4m 26s	remaining: 1h 11m 30s
# 468:	learn: 2.4652479	test: 2.6120032	best: 2.6120032 (468)	total: 4m 27s	remaining: 1h 11m 30s
# 469:	learn: 2.4629524	test: 2.6103062	best: 2.6103062 (469)	total: 4m 27s	remaining: 1h 11m 31s
# 470:	learn: 2.4618345	test: 2.6095260	best: 2.6095260 (470)	total: 4m 28s	remaining: 1h 11m 29s
# 471:	learn: 2.4606749	test: 2.6083956	best: 2.6083956 (471)	total: 4m 28s	remaining: 1h 11m 28s
# 472:	learn: 2.4596772	test: 2.6076144	best: 2.6076144 (472)	total: 4m 29s	remaining: 1h 11m 26s
# 473:	learn: 2.4583167	test: 2.6065009	best: 2.6065009 (473)	total: 4m 29s	remaining: 1h 11m 26s
# 474:	learn: 2.4572749	test: 2.6057145	best: 2.6057145 (474)	total: 4m 30s	remaining: 1h 11m 26s
# 475:	learn: 2.4559434	test: 2.6047103	best: 2.6047103 (475)	total: 4m 31s	remaining: 1h 11m 24s
# 476:	learn: 2.4545268	test: 2.6036073	best: 2.6036073 (476)	total: 4m 31s	remaining: 1h 11m 24s
# 477:	learn: 2.4530659	test: 2.6028337	best: 2.6028337 (477)	total: 4m 32s	remaining: 1h 11m 24s
# 478:	learn: 2.4518714	test: 2.6019376	best: 2.6019376 (478)	total: 4m 32s	remaining: 1h 11m 24s
# 479:	learn: 2.4494531	test: 2.6003795	best: 2.6003795 (479)	total: 4m 33s	remaining: 1h 11m 24s
# 480:	learn: 2.4477380	test: 2.5993915	best: 2.5993915 (480)	total: 4m 34s	remaining: 1h 11m 24s
# 481:	learn: 2.4465194	test: 2.5983980	best: 2.5983980 (481)	total: 4m 34s	remaining: 1h 11m 22s
# 482:	learn: 2.4451831	test: 2.5973547	best: 2.5973547 (482)	total: 4m 35s	remaining: 1h 11m 22s
# 483:	learn: 2.4437633	test: 2.5964276	best: 2.5964276 (483)	total: 4m 35s	remaining: 1h 11m 22s
# 484:	learn: 2.4425659	test: 2.5955055	best: 2.5955055 (484)	total: 4m 36s	remaining: 1h 11m 21s
# 485:	learn: 2.4402835	test: 2.5939164	best: 2.5939164 (485)	total: 4m 36s	remaining: 1h 11m 21s
# 486:	learn: 2.4388332	test: 2.5929510	best: 2.5929510 (486)	total: 4m 37s	remaining: 1h 11m 21s
# 487:	learn: 2.4378696	test: 2.5920722	best: 2.5920722 (487)	total: 4m 38s	remaining: 1h 11m 20s
# 488:	learn: 2.4365431	test: 2.5913446	best: 2.5913446 (488)	total: 4m 38s	remaining: 1h 11m 20s
# 489:	learn: 2.4357005	test: 2.5907299	best: 2.5907299 (489)	total: 4m 39s	remaining: 1h 11m 20s
# 490:	learn: 2.4345974	test: 2.5899318	best: 2.5899318 (490)	total: 4m 39s	remaining: 1h 11m 19s
# 491:	learn: 2.4334788	test: 2.5891850	best: 2.5891850 (491)	total: 4m 40s	remaining: 1h 11m 19s
# 492:	learn: 2.4320639	test: 2.5878978	best: 2.5878978 (492)	total: 4m 41s	remaining: 1h 11m 19s
# 493:	learn: 2.4311309	test: 2.5872236	best: 2.5872236 (493)	total: 4m 41s	remaining: 1h 11m 19s
# 494:	learn: 2.4297866	test: 2.5861340	best: 2.5861340 (494)	total: 4m 42s	remaining: 1h 11m 19s
# 495:	learn: 2.4284902	test: 2.5848585	best: 2.5848585 (495)	total: 4m 42s	remaining: 1h 11m 19s
# 496:	learn: 2.4272765	test: 2.5837066	best: 2.5837066 (496)	total: 4m 43s	remaining: 1h 11m 18s
# 497:	learn: 2.4256169	test: 2.5823660	best: 2.5823660 (497)	total: 4m 44s	remaining: 1h 11m 19s
# 498:	learn: 2.4238256	test: 2.5810452	best: 2.5810452 (498)	total: 4m 44s	remaining: 1h 11m 19s
# 499:	learn: 2.4220437	test: 2.5792099	best: 2.5792099 (499)	total: 4m 45s	remaining: 1h 11m 18s
# 500:	learn: 2.4202213	test: 2.5776697	best: 2.5776697 (500)	total: 4m 45s	remaining: 1h 11m 19s
# 501:	learn: 2.4185254	test: 2.5765306	best: 2.5765306 (501)	total: 4m 46s	remaining: 1h 11m 17s
# 502:	learn: 2.4175625	test: 2.5755726	best: 2.5755726 (502)	total: 4m 46s	remaining: 1h 11m 16s
# ...
# 7836:	learn: 0.5473629	test: 1.7532696	best: 1.7532696 (7836)	total: 1h 19m 11s	remaining: 1m 38s
# 7837:	learn: 0.5472796	test: 1.7532611	best: 1.7532611 (7837)	total: 1h 19m 12s	remaining: 1m 38s
# 7838:	learn: 0.5472446	test: 1.7532621	best: 1.7532611 (7837)	total: 1h 19m 13s	remaining: 1m 37s
# 7839:	learn: 0.5471795	test: 1.7532425	best: 1.7532425 (7839)	total: 1h 19m 13s	remaining: 1m 37s
# 7840:	learn: 0.5470708	test: 1.7532136	best: 1.7532136 (7840)	total: 1h 19m 14s	remaining: 1m 36s
# 7841:	learn: 0.5470430	test: 1.7532113	best: 1.7532113 (7841)	total: 1h 19m 14s	remaining: 1m 35s
# 7842:	learn: 0.5469797	test: 1.7532113	best: 1.7532113 (7841)	total: 1h 19m 15s	remaining: 1m 35s
# 7843:	learn: 0.5469100	test: 1.7532053	best: 1.7532053 (7843)	total: 1h 19m 16s	remaining: 1m 34s
# 7844:	learn: 0.5468393	test: 1.7531976	best: 1.7531976 (7844)	total: 1h 19m 16s	remaining: 1m 33s
# 7845:	learn: 0.5467595	test: 1.7532150	best: 1.7531976 (7844)	total: 1h 19m 17s	remaining: 1m 33s
# 7846:	learn: 0.5466405	test: 1.7531966	best: 1.7531966 (7846)	total: 1h 19m 18s	remaining: 1m 32s
# 7847:	learn: 0.5465627	test: 1.7531663	best: 1.7531663 (7847)	total: 1h 19m 18s	remaining: 1m 32s
# 7848:	learn: 0.5464523	test: 1.7531454	best: 1.7531454 (7848)	total: 1h 19m 19s	remaining: 1m 31s
# 7849:	learn: 0.5463851	test: 1.7531431	best: 1.7531431 (7849)	total: 1h 19m 19s	remaining: 1m 30s
# 7850:	learn: 0.5463111	test: 1.7531388	best: 1.7531388 (7850)	total: 1h 19m 20s	remaining: 1m 30s
# 7851:	learn: 0.5462487	test: 1.7531281	best: 1.7531281 (7851)	total: 1h 19m 21s	remaining: 1m 29s
# 7852:	learn: 0.5462093	test: 1.7531290	best: 1.7531281 (7851)	total: 1h 19m 21s	remaining: 1m 29s
# 7853:	learn: 0.5460974	test: 1.7531255	best: 1.7531255 (7853)	total: 1h 19m 22s	remaining: 1m 28s
# 7854:	learn: 0.5460600	test: 1.7531100	best: 1.7531100 (7854)	total: 1h 19m 23s	remaining: 1m 27s
# 7855:	learn: 0.5459905	test: 1.7531053	best: 1.7531053 (7855)	total: 1h 19m 23s	remaining: 1m 27s
# 7856:	learn: 0.5459559	test: 1.7531135	best: 1.7531053 (7855)	total: 1h 19m 24s	remaining: 1m 26s
# 7857:	learn: 0.5458607	test: 1.7531188	best: 1.7531053 (7855)	total: 1h 19m 24s	remaining: 1m 26s
# 7858:	learn: 0.5458015	test: 1.7531025	best: 1.7531025 (7858)	total: 1h 19m 25s	remaining: 1m 25s
# 7859:	learn: 0.5457074	test: 1.7530593	best: 1.7530593 (7859)	total: 1h 19m 26s	remaining: 1m 24s
# 7860:	learn: 0.5456499	test: 1.7530671	best: 1.7530593 (7859)	total: 1h 19m 26s	remaining: 1m 24s
# 7861:	learn: 0.5455352	test: 1.7530453	best: 1.7530453 (7861)	total: 1h 19m 27s	remaining: 1m 23s
# 7862:	learn: 0.5454038	test: 1.7530205	best: 1.7530205 (7862)	total: 1h 19m 27s	remaining: 1m 23s
# 7863:	learn: 0.5453551	test: 1.7530200	best: 1.7530200 (7863)	total: 1h 19m 28s	remaining: 1m 22s
# 7864:	learn: 0.5453030	test: 1.7530193	best: 1.7530193 (7864)	total: 1h 19m 29s	remaining: 1m 21s
# 7865:	learn: 0.5452070	test: 1.7530191	best: 1.7530191 (7865)	total: 1h 19m 29s	remaining: 1m 21s
# 7866:	learn: 0.5451500	test: 1.7530204	best: 1.7530191 (7865)	total: 1h 19m 30s	remaining: 1m 20s
# 7867:	learn: 0.5451089	test: 1.7530248	best: 1.7530191 (7865)	total: 1h 19m 30s	remaining: 1m 20s
# 7868:	learn: 0.5450927	test: 1.7530128	best: 1.7530128 (7868)	total: 1h 19m 31s	remaining: 1m 19s
# 7869:	learn: 0.5450413	test: 1.7529903	best: 1.7529903 (7869)	total: 1h 19m 31s	remaining: 1m 18s
# 7870:	learn: 0.5449261	test: 1.7529935	best: 1.7529903 (7869)	total: 1h 19m 32s	remaining: 1m 18s
# 7871:	learn: 0.5448448	test: 1.7529878	best: 1.7529878 (7871)	total: 1h 19m 33s	remaining: 1m 17s
# 7872:	learn: 0.5447261	test: 1.7529822	best: 1.7529822 (7872)	total: 1h 19m 33s	remaining: 1m 17s
# 7873:	learn: 0.5446782	test: 1.7529877	best: 1.7529822 (7872)	total: 1h 19m 34s	remaining: 1m 16s
# 7874:	learn: 0.5446085	test: 1.7529696	best: 1.7529696 (7874)	total: 1h 19m 35s	remaining: 1m 15s
# 7875:	learn: 0.5445465	test: 1.7529650	best: 1.7529650 (7875)	total: 1h 19m 35s	remaining: 1m 15s
# 7876:	learn: 0.5444776	test: 1.7529035	best: 1.7529035 (7876)	total: 1h 19m 36s	remaining: 1m 14s
# 7877:	learn: 0.5444254	test: 1.7528938	best: 1.7528938 (7877)	total: 1h 19m 36s	remaining: 1m 13s
# 7878:	learn: 0.5443295	test: 1.7528851	best: 1.7528851 (7878)	total: 1h 19m 37s	remaining: 1m 13s
# 7879:	learn: 0.5442905	test: 1.7528867	best: 1.7528851 (7878)	total: 1h 19m 38s	remaining: 1m 12s
# 7880:	learn: 0.5442043	test: 1.7528763	best: 1.7528763 (7880)	total: 1h 19m 38s	remaining: 1m 12s
# 7881:	learn: 0.5441343	test: 1.7528671	best: 1.7528671 (7881)	total: 1h 19m 39s	remaining: 1m 11s
# 7882:	learn: 0.5440493	test: 1.7528489	best: 1.7528489 (7882)	total: 1h 19m 39s	remaining: 1m 10s
# 7883:	learn: 0.5439595	test: 1.7528273	best: 1.7528273 (7883)	total: 1h 19m 40s	remaining: 1m 10s
# 7884:	learn: 0.5439334	test: 1.7528316	best: 1.7528273 (7883)	total: 1h 19m 41s	remaining: 1m 9s
# 7885:	learn: 0.5438088	test: 1.7528295	best: 1.7528273 (7883)	total: 1h 19m 41s	remaining: 1m 9s
# 7886:	learn: 0.5437800	test: 1.7528225	best: 1.7528225 (7886)	total: 1h 19m 42s	remaining: 1m 8s
# 7887:	learn: 0.5437229	test: 1.7528046	best: 1.7528046 (7887)	total: 1h 19m 42s	remaining: 1m 7s
# 7888:	learn: 0.5436695	test: 1.7527919	best: 1.7527919 (7888)	total: 1h 19m 43s	remaining: 1m 7s
# 7889:	learn: 0.5436306	test: 1.7527888	best: 1.7527888 (7889)	total: 1h 19m 44s	remaining: 1m 6s
# 7890:	learn: 0.5435286	test: 1.7527750	best: 1.7527750 (7890)	total: 1h 19m 44s	remaining: 1m 6s
# 7891:	learn: 0.5434256	test: 1.7527738	best: 1.7527738 (7891)	total: 1h 19m 45s	remaining: 1m 5s
# 7892:	learn: 0.5433603	test: 1.7527640	best: 1.7527640 (7892)	total: 1h 19m 46s	remaining: 1m 4s
# 7893:	learn: 0.5433002	test: 1.7527571	best: 1.7527571 (7893)	total: 1h 19m 46s	remaining: 1m 4s
# 7894:	learn: 0.5432377	test: 1.7527355	best: 1.7527355 (7894)	total: 1h 19m 47s	remaining: 1m 3s
# 7895:	learn: 0.5431530	test: 1.7526908	best: 1.7526908 (7895)	total: 1h 19m 47s	remaining: 1m 3s
# 7896:	learn: 0.5430663	test: 1.7526865	best: 1.7526865 (7896)	total: 1h 19m 48s	remaining: 1m 2s
# 7897:	learn: 0.5429604	test: 1.7526717	best: 1.7526717 (7897)	total: 1h 19m 49s	remaining: 1m 1s
# 7898:	learn: 0.5429064	test: 1.7526635	best: 1.7526635 (7898)	total: 1h 19m 49s	remaining: 1m 1s
# 7899:	learn: 0.5428491	test: 1.7526576	best: 1.7526576 (7899)	total: 1h 19m 50s	remaining: 1m
# 7900:	learn: 0.5427846	test: 1.7526412	best: 1.7526412 (7900)	total: 1h 19m 50s	remaining: 1m
# 7901:	learn: 0.5427183	test: 1.7526399	best: 1.7526399 (7901)	total: 1h 19m 51s	remaining: 59.4s
# 7902:	learn: 0.5426530	test: 1.7526471	best: 1.7526399 (7901)	total: 1h 19m 52s	remaining: 58.8s
# 7903:	learn: 0.5426107	test: 1.7526427	best: 1.7526399 (7901)	total: 1h 19m 52s	remaining: 58.2s
# 7904:	learn: 0.5425498	test: 1.7526376	best: 1.7526376 (7904)	total: 1h 19m 53s	remaining: 57.6s
# 7905:	learn: 0.5424446	test: 1.7526414	best: 1.7526376 (7904)	total: 1h 19m 54s	remaining: 57s
# 7906:	learn: 0.5423561	test: 1.7526541	best: 1.7526376 (7904)	total: 1h 19m 54s	remaining: 56.4s
# 7907:	learn: 0.5423344	test: 1.7526593	best: 1.7526376 (7904)	total: 1h 19m 55s	remaining: 55.8s
# 7908:	learn: 0.5422725	test: 1.7526577	best: 1.7526376 (7904)	total: 1h 19m 55s	remaining: 55.2s
# 7909:	learn: 0.5421477	test: 1.7526065	best: 1.7526065 (7909)	total: 1h 19m 56s	remaining: 54.6s
# 7910:	learn: 0.5420675	test: 1.7526007	best: 1.7526007 (7910)	total: 1h 19m 57s	remaining: 54s
# 7911:	learn: 0.5419990	test: 1.7525367	best: 1.7525367 (7911)	total: 1h 19m 57s	remaining: 53.4s
# 7912:	learn: 0.5418839	test: 1.7525213	best: 1.7525213 (7912)	total: 1h 19m 58s	remaining: 52.8s
# 7913:	learn: 0.5418185	test: 1.7525104	best: 1.7525104 (7913)	total: 1h 19m 58s	remaining: 52.1s
# 7914:	learn: 0.5417682	test: 1.7525122	best: 1.7525104 (7913)	total: 1h 19m 59s	remaining: 51.5s
# 7915:	learn: 0.5416869	test: 1.7524892	best: 1.7524892 (7915)	total: 1h 20m	remaining: 50.9s
# 7916:	learn: 0.5416260	test: 1.7524857	best: 1.7524857 (7916)	total: 1h 20m	remaining: 50.3s
# 7917:	learn: 0.5415639	test: 1.7524859	best: 1.7524857 (7916)	total: 1h 20m 1s	remaining: 49.7s
# 7918:	learn: 0.5415155	test: 1.7524711	best: 1.7524711 (7918)	total: 1h 20m 1s	remaining: 49.1s
# 7919:	learn: 0.5414510	test: 1.7524643	best: 1.7524643 (7919)	total: 1h 20m 2s	remaining: 48.5s
# 7920:	learn: 0.5413984	test: 1.7524614	best: 1.7524614 (7920)	total: 1h 20m 3s	remaining: 47.9s
# 7921:	learn: 0.5413697	test: 1.7524548	best: 1.7524548 (7921)	total: 1h 20m 3s	remaining: 47.3s
# 7922:	learn: 0.5413256	test: 1.7524446	best: 1.7524446 (7922)	total: 1h 20m 4s	remaining: 46.7s
# 7923:	learn: 0.5412544	test: 1.7524339	best: 1.7524339 (7923)	total: 1h 20m 4s	remaining: 46.1s
# 7924:	learn: 0.5411932	test: 1.7524180	best: 1.7524180 (7924)	total: 1h 20m 5s	remaining: 45.5s
# 7925:	learn: 0.5411422	test: 1.7524004	best: 1.7524004 (7925)	total: 1h 20m 6s	remaining: 44.9s
# 7926:	learn: 0.5410677	test: 1.7523837	best: 1.7523837 (7926)	total: 1h 20m 6s	remaining: 44.3s
# 7927:	learn: 0.5409761	test: 1.7523762	best: 1.7523762 (7927)	total: 1h 20m 7s	remaining: 43.7s
# 7928:	learn: 0.5408406	test: 1.7523592	best: 1.7523592 (7928)	total: 1h 20m 8s	remaining: 43.1s
# 7929:	learn: 0.5407220	test: 1.7523422	best: 1.7523422 (7929)	total: 1h 20m 8s	remaining: 42.4s
# 7930:	learn: 0.5406826	test: 1.7523386	best: 1.7523386 (7930)	total: 1h 20m 9s	remaining: 41.8s
# 7931:	learn: 0.5406127	test: 1.7523137	best: 1.7523137 (7931)	total: 1h 20m 10s	remaining: 41.2s
# 7932:	learn: 0.5405624	test: 1.7523031	best: 1.7523031 (7932)	total: 1h 20m 10s	remaining: 40.6s
# 7933:	learn: 0.5405048	test: 1.7522977	best: 1.7522977 (7933)	total: 1h 20m 11s	remaining: 40s
# 7934:	learn: 0.5404095	test: 1.7522721	best: 1.7522721 (7934)	total: 1h 20m 11s	remaining: 39.4s
# 7935:	learn: 0.5403410	test: 1.7522859	best: 1.7522721 (7934)	total: 1h 20m 12s	remaining: 38.8s
# 7936:	learn: 0.5402982	test: 1.7522757	best: 1.7522721 (7934)	total: 1h 20m 13s	remaining: 38.2s
# 7937:	learn: 0.5402373	test: 1.7522648	best: 1.7522648 (7937)	total: 1h 20m 13s	remaining: 37.6s
# 7938:	learn: 0.5401403	test: 1.7522651	best: 1.7522648 (7937)	total: 1h 20m 14s	remaining: 37s
# 7939:	learn: 0.5400573	test: 1.7522545	best: 1.7522545 (7939)	total: 1h 20m 14s	remaining: 36.4s
# 7940:	learn: 0.5399773	test: 1.7522193	best: 1.7522193 (7940)	total: 1h 20m 15s	remaining: 35.8s
# 7941:	learn: 0.5399204	test: 1.7522171	best: 1.7522171 (7941)	total: 1h 20m 16s	remaining: 35.2s
# 7942:	learn: 0.5398771	test: 1.7522046	best: 1.7522046 (7942)	total: 1h 20m 16s	remaining: 34.6s
# 7943:	learn: 0.5398467	test: 1.7522227	best: 1.7522046 (7942)	total: 1h 20m 17s	remaining: 34s
# 7944:	learn: 0.5397795	test: 1.7522233	best: 1.7522046 (7942)	total: 1h 20m 17s	remaining: 33.4s
# 7945:	learn: 0.5397528	test: 1.7522201	best: 1.7522046 (7942)	total: 1h 20m 18s	remaining: 32.7s
# 7946:	learn: 0.5396894	test: 1.7522117	best: 1.7522046 (7942)	total: 1h 20m 19s	remaining: 32.1s
# 7947:	learn: 0.5396437	test: 1.7521947	best: 1.7521947 (7947)	total: 1h 20m 19s	remaining: 31.5s
# 7948:	learn: 0.5395562	test: 1.7521768	best: 1.7521768 (7948)	total: 1h 20m 20s	remaining: 30.9s
# 7949:	learn: 0.5395142	test: 1.7521772	best: 1.7521768 (7948)	total: 1h 20m 20s	remaining: 30.3s
# 7950:	learn: 0.5394034	test: 1.7521514	best: 1.7521514 (7950)	total: 1h 20m 21s	remaining: 29.7s
# 7951:	learn: 0.5393306	test: 1.7521439	best: 1.7521439 (7951)	total: 1h 20m 22s	remaining: 29.1s
# 7952:	learn: 0.5392580	test: 1.7521355	best: 1.7521355 (7952)	total: 1h 20m 22s	remaining: 28.5s
# 7953:	learn: 0.5392131	test: 1.7521390	best: 1.7521355 (7952)	total: 1h 20m 23s	remaining: 27.9s
# 7954:	learn: 0.5390847	test: 1.7521200	best: 1.7521200 (7954)	total: 1h 20m 23s	remaining: 27.3s
# 7955:	learn: 0.5390398	test: 1.7521070	best: 1.7521070 (7955)	total: 1h 20m 24s	remaining: 26.7s
# 7956:	learn: 0.5389218	test: 1.7521112	best: 1.7521070 (7955)	total: 1h 20m 25s	remaining: 26.1s
# 7957:	learn: 0.5388633	test: 1.7521073	best: 1.7521070 (7955)	total: 1h 20m 25s	remaining: 25.5s
# 7958:	learn: 0.5387426	test: 1.7520874	best: 1.7520874 (7958)	total: 1h 20m 26s	remaining: 24.9s
# 7959:	learn: 0.5386741	test: 1.7520697	best: 1.7520697 (7959)	total: 1h 20m 26s	remaining: 24.3s
# 7960:	learn: 0.5386044	test: 1.7520666	best: 1.7520666 (7960)	total: 1h 20m 27s	remaining: 23.6s
# 7961:	learn: 0.5385719	test: 1.7520598	best: 1.7520598 (7961)	total: 1h 20m 28s	remaining: 23s
# 7962:	learn: 0.5384834	test: 1.7520714	best: 1.7520598 (7961)	total: 1h 20m 28s	remaining: 22.4s
# 7963:	learn: 0.5384347	test: 1.7520613	best: 1.7520598 (7961)	total: 1h 20m 29s	remaining: 21.8s
# 7964:	learn: 0.5383257	test: 1.7520580	best: 1.7520580 (7964)	total: 1h 20m 30s	remaining: 21.2s
# 7965:	learn: 0.5382909	test: 1.7520557	best: 1.7520557 (7965)	total: 1h 20m 30s	remaining: 20.6s
# 7966:	learn: 0.5382173	test: 1.7520492	best: 1.7520492 (7966)	total: 1h 20m 31s	remaining: 20s
# 7967:	learn: 0.5381461	test: 1.7520314	best: 1.7520314 (7967)	total: 1h 20m 31s	remaining: 19.4s
# 7968:	learn: 0.5380350	test: 1.7520210	best: 1.7520210 (7968)	total: 1h 20m 32s	remaining: 18.8s
# 7969:	learn: 0.5380133	test: 1.7520188	best: 1.7520188 (7969)	total: 1h 20m 33s	remaining: 18.2s
# 7970:	learn: 0.5379468	test: 1.7520012	best: 1.7520012 (7970)	total: 1h 20m 33s	remaining: 17.6s
# 7971:	learn: 0.5378803	test: 1.7520068	best: 1.7520012 (7970)	total: 1h 20m 34s	remaining: 17s
# 7972:	learn: 0.5378379	test: 1.7519957	best: 1.7519957 (7972)	total: 1h 20m 35s	remaining: 16.4s
# 7973:	learn: 0.5377679	test: 1.7519848	best: 1.7519848 (7973)	total: 1h 20m 35s	remaining: 15.8s
# 7974:	learn: 0.5377334	test: 1.7519796	best: 1.7519796 (7974)	total: 1h 20m 36s	remaining: 15.2s
# 7975:	learn: 0.5376332	test: 1.7519693	best: 1.7519693 (7975)	total: 1h 20m 36s	remaining: 14.6s
# 7976:	learn: 0.5376037	test: 1.7519539	best: 1.7519539 (7976)	total: 1h 20m 37s	remaining: 13.9s
# 7977:	learn: 0.5375719	test: 1.7519418	best: 1.7519418 (7977)	total: 1h 20m 38s	remaining: 13.3s
# 7978:	learn: 0.5374809	test: 1.7518919	best: 1.7518919 (7978)	total: 1h 20m 38s	remaining: 12.7s
# 7979:	learn: 0.5374355	test: 1.7518916	best: 1.7518916 (7979)	total: 1h 20m 39s	remaining: 12.1s
# 7980:	learn: 0.5373223	test: 1.7518728	best: 1.7518728 (7980)	total: 1h 20m 40s	remaining: 11.5s
# 7981:	learn: 0.5372828	test: 1.7518621	best: 1.7518621 (7981)	total: 1h 20m 40s	remaining: 10.9s
# 7982:	learn: 0.5372290	test: 1.7518660	best: 1.7518621 (7981)	total: 1h 20m 41s	remaining: 10.3s
# 7983:	learn: 0.5371096	test: 1.7518813	best: 1.7518621 (7981)	total: 1h 20m 41s	remaining: 9.7s
# 7984:	learn: 0.5370215	test: 1.7518592	best: 1.7518592 (7984)	total: 1h 20m 42s	remaining: 9.1s
# 7985:	learn: 0.5369504	test: 1.7518421	best: 1.7518421 (7985)	total: 1h 20m 43s	remaining: 8.49s
# 7986:	learn: 0.5369150	test: 1.7518295	best: 1.7518295 (7986)	total: 1h 20m 43s	remaining: 7.88s
# 7987:	learn: 0.5368599	test: 1.7518124	best: 1.7518124 (7987)	total: 1h 20m 44s	remaining: 7.28s
# 7988:	learn: 0.5367698	test: 1.7517869	best: 1.7517869 (7988)	total: 1h 20m 44s	remaining: 6.67s
# 7989:	learn: 0.5367316	test: 1.7517843	best: 1.7517843 (7989)	total: 1h 20m 45s	remaining: 6.06s
# 7990:	learn: 0.5366876	test: 1.7517835	best: 1.7517835 (7990)	total: 1h 20m 46s	remaining: 5.46s
# 7991:	learn: 0.5366420	test: 1.7517836	best: 1.7517835 (7990)	total: 1h 20m 46s	remaining: 4.85s
# 7992:	learn: 0.5365961	test: 1.7517698	best: 1.7517698 (7992)	total: 1h 20m 47s	remaining: 4.25s
# 7993:	learn: 0.5365241	test: 1.7517620	best: 1.7517620 (7993)	total: 1h 20m 47s	remaining: 3.64s
# 7994:	learn: 0.5364850	test: 1.7517620	best: 1.7517620 (7993)	total: 1h 20m 48s	remaining: 3.03s
# 7995:	learn: 0.5364366	test: 1.7517569	best: 1.7517569 (7995)	total: 1h 20m 48s	remaining: 2.42s
# 7996:	learn: 0.5363798	test: 1.7517435	best: 1.7517435 (7996)	total: 1h 20m 49s	remaining: 1.82s
# 7997:	learn: 0.5362847	test: 1.7517290	best: 1.7517290 (7997)	total: 1h 20m 50s	remaining: 1.21s
# 7998:	learn: 0.5362301	test: 1.7517256	best: 1.7517256 (7998)	total: 1h 20m 50s	remaining: 606ms
# 7999:	learn: 0.5361298	test: 1.7517151	best: 1.7517151 (7999)	total: 1h 20m 51s	remaining: 0us
# bestTest = 1.751715073
# bestIteration = 7999
# Shrink model to first 8000 iterations.

# %% [markdown]
# #### Helper functions to compare with:

# %%
from sklearn.metrics import explained_variance_score, mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

def show_scores(y_valid,y_pred):
    print("Variance_Score(cat_Regressor)\t:"+str(explained_variance_score(y_valid,y_pred)))
    print("Mean_Absolute_Error(cat_Regressor)\t:"+str(mean_absolute_error(y_valid,y_pred)))
    print("Mean_Squared_Error(cat_Regressor)\t:"+str(mean_squared_error(y_valid,y_pred)))
    print("R2-Score(cat_Regressor)\t:"+str(r2_score(y_valid,y_pred)))
    
def show_feature_importance(model, columns):
    fea_imp = pd.DataFrame({'col': columns, 'imp': model.feature_importances_})
    fea_imp = fea_imp.sort_values(['imp', 'col'], ascending=[True, False]).iloc[-50:]
    fea_imp.plot(kind='barh', x='col', y='imp', figsize=(10, 7), legend=None)
    plt.title('CatBoost - Feature Importance')
    plt.ylabel('Features')
    plt.xlabel('Importance')

# %% [markdown]
# #### 1JHC

# %%
y_pred = model.predict(X_valid)

# %%
show_scores(y_valid, y_pred)

# %%
# no one-hot encoding 3500 iter, D=14 - has molecule structue features + has additional feature enhancements - 
# Only used NB-all_groups removed x_0, y_0.. distances
Variance_Score(cat_Regressor)	:0.9877858291315031
Mean_Absolute_Error(cat_Regressor)	:1.322650231977777
Mean_Squared_Error(cat_Regressor)	:4.084633141161043
R2-Score(cat_Regressor)	:0.9877856592945361

# %%
# no one-hot encoding 2000 iter, D=14 - has molecule structue features + has additional feature enhancements - 
# Only used NB-all_groups removed x_0, y_0.. distances and several more exotic aggregated features
Variance_Score(cat_Regressor)	:0.9861629368065568
Mean_Absolute_Error(cat_Regressor)	:1.42604985165804
Mean_Squared_Error(cat_Regressor)	:4.627380931441835
R2-Score(cat_Regressor)	:0.9861626723092856

# %%
# no one-hot encoding 2000 iter, D=13 - has molecule structue features + has additional feature enhancements - all features
Variance_Score(cat_Regressor)	:0.9866702108698924
Mean_Absolute_Error(cat_Regressor)	:1.4188509095804096
Mean_Squared_Error(cat_Regressor)	:4.457686821267898
R2-Score(cat_Regressor)	:0.9866701111919819

# %%
# no one-hot encoding 2000 iter, D=13 - has molecule structue features + has additional feature enhancements
Variance_Score(cat_Regressor)	:0.9791829473106459
Mean_Absolute_Error(cat_Regressor)	:1.7797263442152451
Mean_Squared_Error(cat_Regressor)	:6.961496290125869
R2-Score(cat_Regressor)	:0.9791829315953573

# %%
# no one-hot encoding 2000 iter, D=13 - only molecule structue features - no additional feature enhancements
Variance_Score(cat_Regressor)	:0.9265082739500486
Mean_Absolute_Error(cat_Regressor)	:3.4439247516519824
Mean_Squared_Error(cat_Regressor)	:24.576762676864877
R2-Score(cat_Regressor)	:0.926507732176107

# %%
# no one-hot encoding 2000 iter, D=13 - only additional feature enhancements - no molecule structue features
Variance_Score(cat_Regressor)	:0.9776194400656896
Mean_Absolute_Error(cat_Regressor)	:1.8409267251192638
Mean_Squared_Error(cat_Regressor)	:7.484393911858465
R2-Score(cat_Regressor)	:0.9776193028715049

# %%
show_feature_importance(model, X_valid.columns)

# %% [markdown]
# ### Let's save the model for later

# %%
model.save_model('./input/models/model_1JHC_8000', format="cbm")

#from catboost import CatBoostClassifier
#model = CatBoostClassifier()      # parameters not required.
#model.load_model('model_name')

# %% [markdown]
# ### Adding predictions to submission file

# %%
import pandas as pd

input_folder = './input'

test = pd.read_csv(f'{input_folder}/test.csv')
structures = pd.read_csv(f'{input_folder}/structures.csv')
molecular_structures = pd.read_csv(f'{input_folder}/molecular_structures_with_NB_test.csv')

# %%
test.head()

# %%
structures.head()

# %%
molecular_structures.head()

# %%
def map_atom_info(df, atom_idx):
    df = pd.merge(df, structures, how = 'left',
                  left_on  = ['molecule_name', f'atom_index_{atom_idx}'],
                  right_on = ['molecule_name',  'atom_index'])
    
    df = df.drop('atom_index', axis=1)
    df = df.rename(columns={'atom': f'atom_{atom_idx}',
                            'x': f'x_{atom_idx}',
                            'y': f'y_{atom_idx}',
                            'z': f'z_{atom_idx}'})
    return df

# %%
test = map_atom_info(test, 0)
test = map_atom_info(test, 1)

# %%
test.head()

# %%
def map_molecule_info(df):
    df = pd.merge(df, molecular_structures, how = 'left',
                  left_on  = ['molecule_name', 'atom_index_0', 'atom_index_1'],
                  right_on = ['molecule_name',  'atom_0', 'atom_1'])
    
    df = df.drop('atom_0_y', axis=1)
    df = df.drop('atom_1_y', axis=1)
    df = df.drop('atom_1_1_level_NB', axis=1)
    df = df.drop('atom_1_2_level_NB', axis=1)
    
    df = df.rename(columns={'atom_0_x': 'atom_0',
                            'atom_1_x': 'atom_1'})
    return df

# %%
test = map_molecule_info(test)

# %%
test.loc[test['molecule_name'] == 'dsgdb9nsd_000015']

# %%
import numpy as np

test.iloc[:,2:4] = test.iloc[:,2:4].astype(np.int8)
test.iloc[:,13:15] = test.iloc[:,13:15].fillna('')
test.iloc[:,15:41] = test.iloc[:,15:41].fillna(0.0).astype(np.int8)
test.iloc[:,42:49] = test.iloc[:,42:49].fillna('')
test.iloc[:,49:57] = test.iloc[:,49:57].fillna(0.0).astype(np.int8)
test.iloc[:,41:42] = test.iloc[:,41:42].fillna(1)

# %%
test.loc[test['molecule_name'] == 'dsgdb9nsd_000015']

# %%
test.dtypes
# Out:
# id                         int64
# molecule_name             object
# atom_index_0                int8
# atom_index_1                int8
# type                      object
# atom_0                    object
# x_0                      float64
# y_0                      float64
# z_0                      float64
# atom_1                    object
# x_1                      float64
# y_1                      float64
# z_1                      float64
# atom_symbol_0             object
# atom_symbol_1             object
# atom_0_CH3                  int8
# atom_1_CH3                  int8
# atom_0_CH2                  int8
# atom_1_CH2                  int8
# atom_0_CH1                  int8
# atom_1_CH1                  int8
# atom_0_CH0                  int8
# atom_1_CH0                  int8
# atom_0_NH2                  int8
# atom_1_NH2                  int8
# atom_0_NH1                  int8
# atom_1_NH1                  int8
# atom_0_NH0                  int8
# atom_1_NH0                  int8
# atom_0_OH1                  int8
# atom_1_OH1                  int8
# atom_0_OH0                  int8
# atom_1_OH0                  int8
# is_in_ring                  int8
# has_aromatic_bond           int8
# is_primary_amide            int8
# is_secondary_amide          int8
# is_tertiary_amide           int8
# is_ester                    int8
# is_carbonyl                 int8
# bond_order                  int8
# bond_length              float64
# NB_left_atom              object
# NB_left_group             object
# NB_center_atom            object
# NB_center_group           object
# NB_right_atom             object
# NB_right_group            object
# NB_all_groups             object
# NB_in_ring                  int8
# NB_is_aromatic              int8
# NB_is_primary_amide         int8
# NB_is_secondary_amide       int8
# NB_is_tertiary_amide        int8
# NB_is_ester                 int8
# NB_is_carbonyl              int8
# NB_is_hydroxyl              int8
# dtype: object

# %%
test = test.drop('atom_symbol_0', axis=1)
test = test.drop('atom_symbol_1', axis=1)
# remove bond lenght as we will calculate our own
test = test.drop('bond_length', axis=1)

# %%
def add_distances(df):
    df['abs_dx']=(df['x_1']-df['x_0']).abs()
    df['abs_dy']=(df['y_1']-df['y_0']).abs()
    df['abs_dz']=(df['z_1']-df['z_0']).abs()
    df['distance']=(df['abs_dx']**2 + df['abs_dy']**2 + df['abs_dz']**2)**(1/2)
    return df

# %%
test=add_distances(test)

# %%
def additional_features(df):
    df['molecule_couples'] = df.groupby('molecule_name')['id'].transform('count')
    df['molecule_dist_mean'] = df.groupby('molecule_name')['distance'].transform('mean')
    df['molecule_dist_min'] = df.groupby('molecule_name')['distance'].transform('min')
    df['molecule_dist_max'] = df.groupby('molecule_name')['distance'].transform('max')
    df['molecule_dist_std'] = df.groupby('molecule_name')['distance'].transform('std')
    df['atom_0_couples_count'] = df.groupby(['molecule_name', 'atom_index_0'])['id'].transform('count')
    df['atom_1_couples_count'] = df.groupby(['molecule_name', 'atom_index_1'])['id'].transform('count')

    num_cols = ['distance'] # 'dx', 'dy', 'dz'
    cat_cols = ['atom_index_0', 'atom_index_1']
    aggs = ['mean', 'std', 'max', 'min']
    for col in cat_cols:
        df[f'molecule_{col}_count'] = df.groupby('molecule_name')[col].transform('count')

    for cat_col in cat_cols:
        for num_col in num_cols:
            for agg in aggs:
                df[f'molecule_{cat_col}_{num_col}_{agg}'] = df.groupby(['molecule_name', cat_col])[num_col].transform(agg)
                df[f'molecule_{cat_col}_{num_col}_{agg}_diff'] = df[f'molecule_{cat_col}_{num_col}_{agg}'] - df[num_col]
                df[f'molecule_{cat_col}_{num_col}_{agg}_div'] = df[f'molecule_{cat_col}_{num_col}_{agg}'] / df[num_col]

    df = reduce_mem_usage(df)
    return df

# %%
test=additional_features(test)
# Out:
# Mem. usage decreased to 707.28 Mb (38.8% reduction)

# %%
test.loc[test['molecule_name'] == 'dsgdb9nsd_000015']

# %%
test[test.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, molecule_name, atom_index_0, atom_index_1, type, atom_0, x_0, y_0, z_0, atom_1, x_1, y_1, z_1, atom_0_CH3, atom_1_CH3, atom_0_CH2, atom_1_CH2, atom_0_CH1, atom_1_CH1, atom_0_CH0, atom_1_CH0, atom_0_NH2, atom_1_NH2, atom_0_NH1, atom_1_NH1, atom_0_NH0, atom_1_NH0, atom_0_OH1, atom_1_OH1, atom_0_OH0, atom_1_OH0, is_in_ring, has_aromatic_bond, is_primary_amide, is_secondary_amide, is_tertiary_amide, is_ester, is_carbonyl, bond_order, NB_left_atom, NB_left_group, NB_center_atom, NB_center_group, NB_right_atom, NB_right_group, NB_all_groups, NB_in_ring, NB_is_aromatic, NB_is_primary_amide, NB_is_secondary_amide, NB_is_tertiary_amide, NB_is_ester, NB_is_carbonyl, NB_is_hydroxyl, abs_dx, abs_dy, abs_dz, distance, molecule_couples, molecule_dist_mean, molecule_dist_min, molecule_dist_max, molecule_dist_std, atom_0_couples_count, atom_1_couples_count, molecule_atom_index_0_count, molecule_atom_index_1_count, molecule_atom_index_0_distance_mean, molecule_atom_index_0_distance_mean_diff, molecule_atom_index_0_distance_mean_div, molecule_atom_index_0_distance_std, molecule_atom_index_0_distance_std_diff, molecule_atom_index_0_distance_std_div, molecule_atom_index_0_distance_max, molecule_atom_index_0_distance_max_diff, molecule_atom_index_0_distance_max_div, molecule_atom_index_0_distance_min, molecule_atom_index_0_distance_min_diff, molecule_atom_index_0_distance_min_div, molecule_atom_index_1_distance_mean, molecule_atom_index_1_distance_mean_diff, molecule_atom_index_1_distance_mean_div, molecule_atom_index_1_distance_std, molecule_atom_index_1_distance_std_diff, molecule_atom_index_1_distance_std_div, molecule_atom_index_1_distance_max, molecule_atom_index_1_distance_max_diff, molecule_atom_index_1_distance_max_div, molecule_atom_index_1_distance_min, molecule_atom_index_1_distance_min_diff, molecule_atom_index_1_distance_min_div]
# Index: []
#
# [0 rows x 91 columns]

# %%
test.NB_all_groups.fillna('', inplace=True)
test.fillna(0, inplace=True)

# %%
test = test.drop('molecule_name', axis=1)
test = test.drop('id', axis=1)

# %%
import gc

del structures
del molecular_structures

gc.collect()
# Out:
# 157

# %%
submission = pd.read_csv('./results/final/many_features_split_type_CAT.csv')

# %%
test.dtypes

# %%
#print(test.NB_left_atom.dtype)
#test.NB_left_atom[test.NB_left_atom == ''] = '0'
test.NB_left_atom.replace('', '0', inplace=True)
test.NB_left_group.replace('', '0', inplace=True)
test.NB_center_atom.replace('', '0', inplace=True)
test.NB_center_group.replace('', '0', inplace=True)
test.NB_right_atom.replace('', '0', inplace=True)
test.NB_right_group.replace('', '0', inplace=True)
test.NB_all_groups.replace('', '0', inplace=True)

# %%
test.head()

# %%
def score_data(index, row):
    row = row.drop(labels=['type'])
    row = row.tolist()
    y_pred = model.predict(row)
    #submission.at[index, 'scalar_coupling_constant'] = y_pred
    #print(submission.at[index, 'scalar_coupling_constant'])
    print(f"Old: {submission.at[index, 'scalar_coupling_constant']}; Pred: {y_pred}")

# %%
counter = 0
for index in range(test.shape[0]):
    counter += 1
    if counter > 500:
        break
    if index % 10000 == 0:
        print("Index: " + str(index))     
    
    row = test.iloc[index, :]
    if row.type in '1JHC':
        score_data(index, row)
# Out:
# Index: 0
# Old: 141.30111365881726; Pred: 61.475358451557085
# Old: 106.41430455062671; Pred: 49.82248632361382
# Old: 86.71258013206806; Pred: 84.89519909850426
# Old: 88.87090457099221; Pred: 82.75426457224754
# Old: 81.76987894706261; Pred: 74.13626842750571
# Old: 88.05240953911924; Pred: 87.2420330121551
# Old: 89.74234387832672; Pred: 81.94386743225834
# Old: 80.59444356504841; Pred: 76.06174014551539
# Old: 104.32774437785156; Pred: 60.166517578772044
# Old: 102.8861032588802; Pred: 60.52218934493976
# Old: 105.62051911707886; Pred: 66.79296606707126
# Old: 110.61095176805406; Pred: 64.93987158947996
# Old: 106.68053564150479; Pred: 59.69297396095054
# Old: 102.9815424168202; Pred: 56.41515981104614
# Old: 80.2374946444969; Pred: 80.14078577208421
# Old: 82.50009767999518; Pred: 80.15640170169368
# Old: 84.52158738507988; Pred: 85.66081261468109
# Old: 90.33227990692274; Pred: 87.30972111360592
# Old: 84.99110763099003; Pred: 84.33516032874765
# Old: 83.29014184402881; Pred: 83.15185348770878
# Old: 80.70023452543694; Pred: 76.47317615765087
# Old: 198.7643646374344; Pred: 196.38964634381142
# Old: 85.7223802180408; Pred: 85.39979903269504
# Old: 83.70377251083049; Pred: 82.98788943801303
# Old: 84.85745017361607; Pred: 83.99438583114762
# Old: 84.11695237406869; Pred: 78.85709436680871
# Old: 89.4858900875929; Pred: 82.40982786518764
# Old: 106.46212154675169; Pred: 101.46729671813401
# Old: 85.9371036608116; Pred: 85.69583085895556
# Old: 85.95884267634659; Pred: 86.02525623500757
# Old: 90.25255112067272; Pred: 94.5228683615459
# Old: 109.21329628898457; Pred: 100.69351658218926
# Old: 86.20651049175034; Pred: 85.67721542831946
# Old: 80.89211430752029; Pred: 80.93614187002737
# Old: 86.18254453977949; Pred: 84.8692701392815
# Old: 89.40156464729273; Pred: 85.52298817320083
# Old: 86.57840465688679; Pred: 84.06073523396898
# Old: 91.3406810472477; Pred: 91.80578154359925
# Old: 92.17363026853356; Pred: 92.57529504287699
# Old: 80.39514502958448; Pred: 81.73282315930753
# Old: 89.41840815511225; Pred: 92.068353928654
# Old: 91.08840482887916; Pred: 88.35117315624274
# Old: 86.39006581193577; Pred: 87.10270917003368
# Old: 90.18748431962328; Pred: 88.75888046650641
# Old: 85.29481936849724; Pred: 85.17435360245365
# Old: 82.76338407675203; Pred: 81.79811763714798
# Old: 83.59474146994219; Pred: 81.88963846960266
# Old: 100.56119916513512; Pred: 94.77429211744777
# Old: 104.69644101105726; Pred: 102.4187168061472
# Old: 105.58101645140258; Pred: 105.68562446667042
# Old: 101.88421698377421; Pred: 100.7691050030351
# Old: 104.06259044779301; Pred: 96.99005032340449
# Old: 90.87292795282795; Pred: 90.41304353283225
# Old: 84.9881298692373; Pred: 84.37152212923208
# Old: 84.70990061897065; Pred: 83.82451216205403
# Old: 105.53500203411691; Pred: 102.08967534086882
# Old: 110.21277034575495; Pred: 107.20140026290547
# Old: 102.14738517431394; Pred: 105.1415867927251
# Old: 105.1282732664848; Pred: 97.84283014892674
# Old: 88.98429503334961; Pred: 84.02556936368805
# Old: 87.6983276418087; Pred: 83.47232842955874
# Old: 87.49971640662554; Pred: 90.92913293130091
# Old: 87.72867346913013; Pred: 88.22568333892522
# Old: 88.34168952946783; Pred: 89.77234327110563
# Old: 89.64721479627147; Pred: 86.68134905295544
# Old: 81.94747350649865; Pred: 76.4757325370932
# Old: 81.39862991572542; Pred: 74.5993238484288
# Old: 82.41392328463914; Pred: 75.05015310703614
# Old: 82.48308188731383; Pred: 76.88088813508173
# Old: 81.12474344821263; Pred: 75.60159338066927
# Old: 81.5829081175855; Pred: 76.34130375368832
# Old: 81.4965104224747; Pred: 77.3889797713771
# Old: 82.46660043899615; Pred: 76.28068865499014
# Old: 82.01638118899281; Pred: 76.81583972177876
# Old: 81.65516251108309; Pred: 76.88897250848842
# Old: 83.03492504189026; Pred: 76.17473847849189
# Old: 82.40736950940166; Pred: 76.56277399339842
# Old: 115.24113998880716; Pred: 117.61849713333149
# Old: 84.5073831765092; Pred: 83.26175350661633
# Old: 86.63248122778671; Pred: 86.35307902465306
# Old: 84.13178384417009; Pred: 84.16506866158329
# Old: 86.35731656804113; Pred: 85.83528387300981
# Old: 85.02863017067114; Pred: 86.43344723950233
# Old: 84.20135350905608; Pred: 82.97460012867143
# Old: 83.37346654116449; Pred: 83.77791606297555
# Old: 82.75196246849039; Pred: 81.79136923485186
# Old: 83.15648433440853; Pred: 83.61521020056253
# Old: 85.54331780014033; Pred: 85.41603304334102
# Old: 85.90419708743809; Pred: 89.07203529433222
# Old: 101.72281941243546; Pred: 99.04409486493807
# Old: 83.80811194206571; Pred: 85.84966812824835
# Old: 89.79701156018677; Pred: 90.91153004776884
# Old: 83.62804131816097; Pred: 85.80338107095723
# Old: 85.03235984213187; Pred: 87.4143676935668

# %%
def score_data(index, row):
    row = row.drop(labels=['type'])
    row = row.tolist()
    y_pred = model.predict(row)
    submission.at[index, 'scalar_coupling_constant'] = y_pred

# %%
for index in range(test.shape[0]):
    if index % 10000 == 0:
        print("Index: " + str(index))     
    
    row = test.iloc[index, :]
    if row.type in '1JHC':
        score_data(index, row)
# Out:
# Index: 0
# Index: 10000
# Index: 20000
# Index: 30000
# Index: 40000
# Index: 50000
# Index: 60000
# Index: 70000
# Index: 80000
# Index: 90000
# Index: 100000
# Index: 110000
# Index: 120000
# Index: 130000
# Index: 140000
# Index: 150000
# Index: 160000
# Index: 170000
# Index: 180000
# Index: 190000
# Index: 200000
# Index: 210000
# Index: 220000
# Index: 230000
# Index: 240000
# Index: 250000
# Index: 260000
# Index: 270000
# Index: 280000
# Index: 290000
# Index: 300000
# Index: 310000
# Index: 320000
# Index: 330000
# Index: 340000
# Index: 350000
# Index: 360000
# Index: 370000
# Index: 380000
# Index: 390000
# Index: 400000
# Index: 410000
# Index: 420000
# Index: 430000
# Index: 440000
# Index: 450000
# Index: 460000
# Index: 470000
# Index: 480000
# Index: 490000
# Index: 500000
# Index: 510000
# Index: 520000
# Index: 530000
# Index: 540000
# Index: 550000
# Index: 560000
# Index: 570000
# Index: 580000
# Index: 590000
# Index: 600000
# Index: 610000
# Index: 620000
# Index: 630000
# Index: 640000
# Index: 650000
# Index: 660000
# Index: 670000
# Index: 680000
# Index: 690000
# Index: 700000
# Index: 710000
# Index: 720000
# Index: 730000
# Index: 740000
# Index: 750000
# Index: 760000
# Index: 770000
# Index: 780000
# Index: 790000
# Index: 800000
# Index: 810000
# Index: 820000
# Index: 830000
# Index: 840000
# Index: 850000
# Index: 860000
# Index: 870000
# Index: 880000
# Index: 890000
# Index: 900000
# Index: 910000
# Index: 920000
# Index: 930000
# Index: 940000
# Index: 950000
# Index: 960000
# Index: 970000
# Index: 980000
# Index: 990000
# Index: 1000000
# Index: 1010000
# Index: 1020000
# Index: 1030000
# Index: 1040000
# Index: 1050000
# Index: 1060000
# Index: 1070000
# Index: 1080000
# Index: 1090000
# Index: 1100000
# Index: 1110000
# Index: 1120000
# Index: 1130000
# Index: 1140000
# Index: 1150000
# Index: 1160000
# Index: 1170000
# Index: 1180000
# Index: 1190000
# Index: 1200000
# Index: 1210000
# Index: 1220000
# Index: 1230000
# Index: 1240000
# Index: 1250000
# Index: 1260000
# Index: 1270000
# Index: 1280000
# Index: 1290000
# Index: 1300000
# Index: 1310000
# Index: 1320000
# Index: 1330000
# Index: 1340000
# Index: 1350000
# Index: 1360000
# Index: 1370000
# Index: 1380000
# Index: 1390000
# Index: 1400000
# Index: 1410000
# Index: 1420000
# Index: 1430000
# Index: 1440000
# Index: 1450000
# Index: 1460000
# Index: 1470000
# Index: 1480000
# Index: 1490000
# Index: 1500000
# Index: 1510000
# Index: 1520000
# Index: 1530000
# Index: 1540000
# Index: 1550000
# Index: 1560000
# Index: 1570000
# Index: 1580000
# Index: 1590000
# Index: 1600000
# Index: 1610000
# Index: 1620000
# Index: 1630000
# Index: 1640000
# Index: 1650000
# Index: 1660000
# Index: 1670000
# Index: 1680000
# Index: 1690000
# Index: 1700000
# Index: 1710000
# Index: 1720000
# Index: 1730000
# Index: 1740000
# Index: 1750000
# Index: 1760000
# Index: 1770000
# Index: 1780000
# Index: 1790000
# Index: 1800000
# Index: 1810000
# Index: 1820000
# Index: 1830000
# Index: 1840000
# Index: 1850000
# Index: 1860000
# Index: 1870000
# Index: 1880000
# Index: 1890000
# Index: 1900000
# Index: 1910000
# Index: 1920000
# Index: 1930000
# Index: 1940000
# Index: 1950000
# Index: 1960000
# Index: 1970000
# Index: 1980000
# Index: 1990000
# Index: 2000000
# Index: 2010000
# Index: 2020000
# Index: 2030000
# Index: 2040000
# Index: 2050000
# Index: 2060000
# Index: 2070000
# Index: 2080000
# Index: 2090000
# Index: 2100000
# Index: 2110000
# Index: 2120000
# Index: 2130000
# Index: 2140000
# Index: 2150000
# Index: 2160000
# Index: 2170000
# Index: 2180000
# Index: 2190000
# Index: 2200000
# Index: 2210000
# Index: 2220000
# Index: 2230000
# Index: 2240000
# Index: 2250000
# Index: 2260000
# Index: 2270000
# Index: 2280000
# Index: 2290000
# Index: 2300000
# Index: 2310000
# Index: 2320000
# Index: 2330000
# Index: 2340000
# Index: 2350000
# Index: 2360000
# Index: 2370000
# Index: 2380000
# Index: 2390000
# Index: 2400000
# Index: 2410000
# Index: 2420000
# Index: 2430000
# Index: 2440000
# Index: 2450000
# Index: 2460000
# Index: 2470000
# Index: 2480000
# Index: 2490000
# Index: 2500000

# %%
submission.to_csv('./results/final/many_features_split_type_CAT_1JHC.csv', index=False)
